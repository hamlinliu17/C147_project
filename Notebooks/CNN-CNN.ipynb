# %% [markdown]
# #CNN-CNN notebook
# This is the model for the CNN generator and CNN discriminator

# %%
import os
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
os.chdir('/content/drive/My Drive/c147_project/')
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import os
import time
from data import eegData
import numpy as np
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
# get the device type of machine
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
train_dataset = eegData('data/X_train_valid.npy', 'data/y_train_valid.npy', device, preprocessing_params={'subsample':6, 'trim':400})
# Out:
# cuda

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import os
import time
import numpy as np
import matplotlib.pyplot as plt
# !pip install torchinfo --quiet
import torchinfo

def count_parameters(model):
  """Function for count model's parameters"""
  return sum(p.numel() for p in model.parameters() if p.requires_grad)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
class CNNGenerator(nn.Module):
  def __init__(self,input_dim,hidden_dims):
    super(CNNGenerator,self).__init__()
    self.input_dim = input_dim
    self.l1 = nn.Sequential(
        nn.ConvTranspose1d(self.input_dim,hidden_dims[0],4,2,0, bias = False),
        nn.BatchNorm1d(hidden_dims[0]),
        nn.ReLU(True)
    )
    self.l2 = nn.Sequential(
        nn.ConvTranspose1d(hidden_dims[0],hidden_dims[1],4,2,0, bias = False),
        nn.BatchNorm1d(hidden_dims[1]),
        nn.ReLU(True)
    )
    self.l3 = nn.Sequential(
        nn.ConvTranspose1d(hidden_dims[1],hidden_dims[2],4,2,0, bias = False),
        nn.BatchNorm1d(hidden_dims[2]),
        nn.ReLU(True)
    )
    self.l4 = nn.Sequential(
        nn.ConvTranspose1d(hidden_dims[2],hidden_dims[3],7,2,0, bias = False),
        nn.BatchNorm1d(hidden_dims[3]),
        nn.ReLU(True)
    )
    self.l5 = nn.Sequential(
        nn.ConvTranspose1d(hidden_dims[3],22,4,2,0, bias = False),
        nn.Tanh()
    )
    
  def forward(self,input):
    l1 = self.l1(input) 
    l2 = self.l2(l1)
    l3 = self.l3(l2)
    l4 = self.l4(l3)
    l5 = self.l5(l4)
    # print(l1.shape[2],l2.shape[2],l3.shape[2],l4.shape[2],l5.shape[2])
    return l5



# class Generator(nn.Module):
#     def __init__(self, ngpu):
#         super(Generator, self).__init__()
#         self.ngpu = ngpu
#         self.main = nn.Sequential(
#             # input is Z, going into a convolution
#             nn.ConvTranspose2d( nz, ngf * 8, 4, 1, 0, bias=False),
#             nn.BatchNorm2d(ngf * 8),
#             nn.ReLU(True),
#             # state size. (ngf*8) x 4 x 4
#             nn.ConvTranspose2d(ngf * 8, ngf * 4, 4, 2, 1, bias=False),
#             nn.BatchNorm2d(ngf * 4),
#             nn.ReLU(True),
#             # state size. (ngf*4) x 8 x 8
#             nn.ConvTranspose2d( ngf * 4, ngf * 2, 4, 2, 1, bias=False),
#             nn.BatchNorm2d(ngf * 2),
#             nn.ReLU(True),
#             # state size. (ngf*2) x 16 x 16
#             nn.ConvTranspose2d( ngf * 2, ngf, 4, 2, 1, bias=False),
#             nn.BatchNorm2d(ngf),
#             nn.ReLU(True),
#             # state size. (ngf) x 32 x 32
#             nn.ConvTranspose2d( ngf, nc, 4, 2, 1, bias=False),
#             nn.Tanh()
#             # state size. (nc) x 64 x 64
#         )

#     def forward(self, input):
#         return self.main(input)

# %%
class CNNDiscriminator(nn.Module):
  """
  Discriminator that uses CNN layers
  follows the DCGAN of the pytorch tutorial
  https://pytorch.org/tutorials/beginner/dcgan_faces_tutorial.html
  input is (batch, in_dim, seq)
  output is (batch, 1, seq)
  """
  def __init__(self, input_dim, hidden_dims):
    super(CNNDiscriminator, self).__init__()
    assert len(hidden_dims) == 4
    self.conv1 = nn.Sequential(
        nn.Conv1d(input_dim, hidden_dims[0], 3, 2, 1, bias=False),
        nn.LeakyReLU(0.2, inplace=True)
    ) # output batch x dim1 x 50
    self.conv2 = nn.Sequential(
        nn.Conv1d(hidden_dims[0], hidden_dims[1], 3, 2, 1, bias=False),
        nn.BatchNorm1d(hidden_dims[1]),
        nn.LeakyReLU(0.2, inplace=True),
    ) # ouptut batch x dim2 x 25
    self.conv3 = nn.Sequential(
        nn.Conv1d(hidden_dims[1], hidden_dims[2], 3, 2, 1, bias=False),
        nn.BatchNorm1d(hidden_dims[2]),
        nn.LeakyReLU(0.2, inplace=True),
    )# ouptut batch x dim3 x 13

    self.conv4 = nn.Sequential(
        nn.Conv1d(hidden_dims[2], hidden_dims[3], 3, 2, 1, bias=False),
        nn.BatchNorm1d(hidden_dims[3]),
        nn.LeakyReLU(0.2, inplace=True),
    )# ouptut batch x dim3 x 7

    self.end = nn.Sequential(
        nn.Conv1d(hidden_dims[3], 1, 3, 2, 1, bias=False),
        nn.BatchNorm1d(1),
        nn.LeakyReLU(0.2, inplace=True),
        nn.Conv1d(1, 1, 4, 1, 0, bias=False),
        nn.Sigmoid()
    )



  def forward(self, x):
    return self.end(self.conv4(self.conv3(self.conv2(self.conv1(x)))))

# %%
class GAN(object):
  """
  Class object to control and abstract the training and logging of vanilla GANs
  Assumes that the noise input or z vector is (batch_size, 2, 600) 
    where the first channel is noise and the second channel is the label
  """
  def __init__(self,
               generator: nn.Module,
               discriminator: nn.Module,
               train_valid_data: eegData,
               **kwargs
               ):
    self.G = generator
    self.D = discriminator
    self.loss = nn.BCELoss()
    self.dataset = train_valid_data
    # checking for CUDA acceleration
    # move parameters to Cuda
    # establish before the optimizer and loss
    self.cuda_bool = kwargs.get('cuda', False)
    self.cuda_device = kwargs.get('device', 0)
    self.device = torch.device('cpu')
    if self.cuda_bool:
      print("Establishing network on CUDA device: ", torch.cuda.get_device_name(self.cuda_device))
      self.device = torch.device('cuda')
      self.G.cuda(self.cuda_device)
      self.D.cuda(self.cuda_device)
      self.loss.cuda(self.cuda_device)
    
    # setting up optimizers
    lr = kwargs.get('learn_rate', 0.0002)
    w_decay = kwargs.get('weight_decay', 0.00001)
    self.d_optimizer = torch.optim.Adam(self.D.parameters(), lr=lr, weight_decay=w_decay)
    self.g_optimizer = torch.optim.Adam(self.G.parameters(), lr=lr, weight_decay=w_decay)


  def train(self, 
            epochs, batch_size, save_path, verbose=True, print_every=100):
    
    
    self.epochs = epochs

    self.batch_size = batch_size

    self.G_loss = list()
    self.D_loss = list()
    self.generated_test = list()

    # setup the loader
    data_loader = torch.utils.data.DataLoader(self.dataset, batch_size=batch_size, shuffle=True)

    iteration = 0

    # TODO: change the input
    fixed_z = torch.rand((1, self.G.input_dim - 1, 1), device=self.device)
    fixed_labels = torch.zeros((1 , 1), device=self.device).reshape(-1, 1).repeat(1, 1).reshape(-1, 1, 1)
    fixed_z = torch.cat([fixed_z, fixed_labels], dim=1).to(self.device)
    real_label = 1
    fake_label = 0
    for epoch in range(self.epochs + 1):
      for i, sample in enumerate(data_loader):
        # What to do for each batch

        if i == data_loader.dataset.__len__() // self.batch_size:
          break

        self.G.train()

        # assert data and labels
        eeg_data = sample['data']
        eeg_labels = sample['label']

        # input vector for 
        noise = torch.rand((self.batch_size, self.G.input_dim - 1, 1), device=self.device)
        labels = eeg_labels.reshape(-1, 1).repeat(1, 1).reshape(-1, 1, 1)
        
        z = torch.cat([noise, labels], dim=1)

        seq_length = eeg_data.shape[2]

        benchmark = torch.full((self.batch_size, 1, 1), real_label, device=self.device, dtype=torch.float)

        # attach to cuda
        if self.cuda_bool:
          eeg_data = Variable(eeg_data.cuda(self.cuda_device))
          z = Variable(z.cuda(self.cuda_device))
        else:
          eeg_data = Variable(eeg_data)
          z = Variable(z)
        

        ##############
        # Training the Discriminator
        ##############
        self.d_optimizer.zero_grad()
        self.D.zero_grad() # remove previous gradients
        # train the discriminator on real data
        real_score = self.D(eeg_data)
        d_loss_real = self.loss(real_score, benchmark)
        d_loss_real.backward()
        real_output_score = real_score.mean().item()

        # train the discriminator on fake data

        benchmark.fill_(fake_label)
        fake_data = self.G(z)
        fake_score = self.D(fake_data.detach())
        d_loss_fake = self.loss(fake_score, benchmark)
        d_loss_fake.backward()
        # print(fake_score)
        G_output_score1 = fake_score.mean().item()
        

        # optimize the discriminator
        d_loss = d_loss_real + d_loss_fake
        self.d_optimizer.step()


        ##############
        # Training the Generator
        ##############
        self.G.zero_grad() # remove previous gradients
        self.g_optimizer.zero_grad()

        benchmark.fill_(real_label)
        fake_score2 = self.D(fake_data)
        G_output_score2 = fake_score2.mean().item()
        g_loss = self.loss(fake_score2, benchmark)
        g_loss.backward()
        self.g_optimizer.step()

        iteration += 1
        
        if iteration % print_every == 0 and verbose:
          # output the loss and the scores
          print("Iteration : ", iteration)
          print('[%d/%d][%d/%d]\tLoss_D: %.4f\tLoss_G: %.4f\tReal Score: %.4f\t Fake Scores: %.4f / %.4f'
                  % (epoch, self.epochs, i, len(data_loader),
                     d_loss.item(), g_loss.item(), real_output_score, G_output_score1, G_output_score2))
          
        self.G_loss.append(g_loss.cpu().item())
        self.D_loss.append(d_loss.cpu().item())

      # check how the Generator is doing
      with torch.no_grad() :
        self.G.eval()
        fake_data = self.G(fixed_z).detach().cpu()
        self.generated_test.append(np.mean(fake_data.numpy(), axis=(0, 1)))


      if epoch % 250 == 0:
        save_str = save_path + '/Generator_' + str(epoch) + '.pth'
        self.save_models(save_str)


  def save_models(self, path):
    torch.save(self.G.state_dict(), path)
    print("Saved generator at " + path)
    return True

# %%
# testinp = torch.rand((1,99,1))
# test_label = torch.zeros((1,1,1))
# inp = torch.cat([testinp, test_label], dim = 1)
# input.shape
Gen = CNNGenerator(100,[220,154,88,44])
# x = Gen(inp)

dis = CNNDiscriminator(22,[18, 14, 10 , 6])
# dis(x).shape

gan = GAN(Gen,dis,train_dataset,cuda = True)

# %%
gan.train(5000,250, save_path='/content/drive/My Drive/c147_project/Models/CNN-CNN')
# Out:
# Streaming output truncated to the last 5000 lines.
# Iteration :  1100
# [21/5000][49/51]	Loss_D: 1.4286	Loss_G: 0.5388	Real Score: 0.5761	 Fake Scores: 0.5835 / 0.5835
# Iteration :  1200
# [23/5000][49/51]	Loss_D: 1.4237	Loss_G: 0.5494	Real Score: 0.5705	 Fake Scores: 0.5774 / 0.5773
# Iteration :  1300
# [25/5000][49/51]	Loss_D: 1.4146	Loss_G: 0.5595	Real Score: 0.5676	 Fake Scores: 0.5716 / 0.5715
# Iteration :  1400
# [27/5000][49/51]	Loss_D: 1.4074	Loss_G: 0.5692	Real Score: 0.5644	 Fake Scores: 0.5660 / 0.5660
# Iteration :  1500
# [29/5000][49/51]	Loss_D: 1.3916	Loss_G: 0.5791	Real Score: 0.5664	 Fake Scores: 0.5605 / 0.5604
# Iteration :  1600
# [31/5000][49/51]	Loss_D: 1.3631	Loss_G: 0.5898	Real Score: 0.5752	 Fake Scores: 0.5545 / 0.5544
# Iteration :  1700
# [33/5000][49/51]	Loss_D: 1.4371	Loss_G: 0.5341	Real Score: 0.5755	 Fake Scores: 0.5864 / 0.5862
# Iteration :  1800
# [35/5000][49/51]	Loss_D: 1.4170	Loss_G: 0.5576	Real Score: 0.5678	 Fake Scores: 0.5727 / 0.5726
# Iteration :  1900
# [37/5000][49/51]	Loss_D: 1.4027	Loss_G: 0.5760	Real Score: 0.5622	 Fake Scores: 0.5622 / 0.5621
# Iteration :  2000
# [39/5000][49/51]	Loss_D: 1.3830	Loss_G: 0.5932	Real Score: 0.5609	 Fake Scores: 0.5527 / 0.5526
# Iteration :  2100
# [41/5000][49/51]	Loss_D: 1.3603	Loss_G: 0.6094	Real Score: 0.5627	 Fake Scores: 0.5437 / 0.5437
# Iteration :  2200
# [43/5000][49/51]	Loss_D: 1.4322	Loss_G: 0.5569	Real Score: 0.5601	 Fake Scores: 0.5730 / 0.5730
# Iteration :  2300
# [45/5000][49/51]	Loss_D: 1.4158	Loss_G: 0.5682	Real Score: 0.5606	 Fake Scores: 0.5666 / 0.5666
# Iteration :  2400
# [47/5000][49/51]	Loss_D: 1.4072	Loss_G: 0.5792	Real Score: 0.5573	 Fake Scores: 0.5604 / 0.5604
# Iteration :  2500
# [49/5000][49/51]	Loss_D: 1.4010	Loss_G: 0.5890	Real Score: 0.5538	 Fake Scores: 0.5549 / 0.5549
# Iteration :  2600
# [51/5000][49/51]	Loss_D: 1.3926	Loss_G: 0.5981	Real Score: 0.5521	 Fake Scores: 0.5499 / 0.5499
# Iteration :  2700
# [53/5000][49/51]	Loss_D: 1.3802	Loss_G: 0.6072	Real Score: 0.5529	 Fake Scores: 0.5449 / 0.5449
# Iteration :  2800
# [55/5000][49/51]	Loss_D: 1.3619	Loss_G: 0.6170	Real Score: 0.5567	 Fake Scores: 0.5396 / 0.5396
# Iteration :  2900
# [57/5000][49/51]	Loss_D: 1.4071	Loss_G: 0.5806	Real Score: 0.5563	 Fake Scores: 0.5596 / 0.5596
# Iteration :  3000
# [59/5000][49/51]	Loss_D: 1.4025	Loss_G: 0.5931	Real Score: 0.5501	 Fake Scores: 0.5527 / 0.5526
# Iteration :  3100
# [61/5000][49/51]	Loss_D: 1.3990	Loss_G: 0.6037	Real Score: 0.5449	 Fake Scores: 0.5468 / 0.5468
# Iteration :  3200
# [63/5000][49/51]	Loss_D: 1.3961	Loss_G: 0.6129	Real Score: 0.5404	 Fake Scores: 0.5418 / 0.5418
# Iteration :  3300
# [65/5000][49/51]	Loss_D: 1.3942	Loss_G: 0.6210	Real Score: 0.5363	 Fake Scores: 0.5374 / 0.5374
# Iteration :  3400
# [67/5000][49/51]	Loss_D: 1.3929	Loss_G: 0.6282	Real Score: 0.5326	 Fake Scores: 0.5336 / 0.5335
# Iteration :  3500
# [69/5000][49/51]	Loss_D: 1.3914	Loss_G: 0.6347	Real Score: 0.5294	 Fake Scores: 0.5301 / 0.5301
# Iteration :  3600
# [71/5000][49/51]	Loss_D: 1.3906	Loss_G: 0.6405	Real Score: 0.5264	 Fake Scores: 0.5271 / 0.5270
# Iteration :  3700
# [73/5000][49/51]	Loss_D: 1.3897	Loss_G: 0.6457	Real Score: 0.5238	 Fake Scores: 0.5243 / 0.5243
# Iteration :  3800
# [75/5000][49/51]	Loss_D: 1.3892	Loss_G: 0.6506	Real Score: 0.5213	 Fake Scores: 0.5218 / 0.5218
# Iteration :  3900
# [77/5000][49/51]	Loss_D: 1.3886	Loss_G: 0.6550	Real Score: 0.5191	 Fake Scores: 0.5195 / 0.5195
# Iteration :  4000
# [79/5000][49/51]	Loss_D: 1.3883	Loss_G: 0.6590	Real Score: 0.5170	 Fake Scores: 0.5174 / 0.5174
# Iteration :  4100
# [81/5000][49/51]	Loss_D: 1.3879	Loss_G: 0.6627	Real Score: 0.5151	 Fake Scores: 0.5155 / 0.5154
# Iteration :  4200
# [83/5000][49/51]	Loss_D: 1.3877	Loss_G: 0.6661	Real Score: 0.5134	 Fake Scores: 0.5137 / 0.5137
# Iteration :  4300
# [85/5000][49/51]	Loss_D: 1.3874	Loss_G: 0.6693	Real Score: 0.5118	 Fake Scores: 0.5121 / 0.5121
# Iteration :  4400
# [87/5000][49/51]	Loss_D: 1.3872	Loss_G: 0.6722	Real Score: 0.5104	 Fake Scores: 0.5106 / 0.5106
# Iteration :  4500
# [89/5000][49/51]	Loss_D: 1.3871	Loss_G: 0.6749	Real Score: 0.5090	 Fake Scores: 0.5092 / 0.5092
# Iteration :  4600
# [91/5000][49/51]	Loss_D: 1.3870	Loss_G: 0.6773	Real Score: 0.5078	 Fake Scores: 0.5080 / 0.5080
# Iteration :  4700
# [93/5000][49/51]	Loss_D: 1.3869	Loss_G: 0.6795	Real Score: 0.5067	 Fake Scores: 0.5069 / 0.5069
# Iteration :  4800
# [95/5000][49/51]	Loss_D: 1.3868	Loss_G: 0.6815	Real Score: 0.5057	 Fake Scores: 0.5058 / 0.5058
# Iteration :  4900
# [97/5000][49/51]	Loss_D: 1.3868	Loss_G: 0.6834	Real Score: 0.5047	 Fake Scores: 0.5049 / 0.5049
# Iteration :  5000
# [99/5000][49/51]	Loss_D: 1.3867	Loss_G: 0.6850	Real Score: 0.5039	 Fake Scores: 0.5041 / 0.5041
# Iteration :  5100
# [101/5000][49/51]	Loss_D: 1.3866	Loss_G: 0.6865	Real Score: 0.5032	 Fake Scores: 0.5033 / 0.5033
# Iteration :  5200
# [103/5000][49/51]	Loss_D: 1.3866	Loss_G: 0.6879	Real Score: 0.5025	 Fake Scores: 0.5027 / 0.5027
# Iteration :  5300
# [105/5000][49/51]	Loss_D: 1.3866	Loss_G: 0.6890	Real Score: 0.5019	 Fake Scores: 0.5021 / 0.5021
# Iteration :  5400
# [107/5000][49/51]	Loss_D: 1.3865	Loss_G: 0.6901	Real Score: 0.5014	 Fake Scores: 0.5016 / 0.5015
# Iteration :  5500
# [109/5000][49/51]	Loss_D: 1.3865	Loss_G: 0.6910	Real Score: 0.5010	 Fake Scores: 0.5011 / 0.5011
# Iteration :  5600
# [111/5000][49/51]	Loss_D: 1.3865	Loss_G: 0.6917	Real Score: 0.5006	 Fake Scores: 0.5007 / 0.5007
# Iteration :  5700
# [113/5000][49/51]	Loss_D: 1.3865	Loss_G: 0.6924	Real Score: 0.5003	 Fake Scores: 0.5004 / 0.5004
# Iteration :  5800
# [115/5000][49/51]	Loss_D: 1.3865	Loss_G: 0.6930	Real Score: 0.5000	 Fake Scores: 0.5001 / 0.5001
# Iteration :  5900
# [117/5000][49/51]	Loss_D: 1.3865	Loss_G: 0.6934	Real Score: 0.4998	 Fake Scores: 0.4999 / 0.4999
# Iteration :  6000
# [119/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6938	Real Score: 0.4996	 Fake Scores: 0.4997 / 0.4997
# Iteration :  6100
# [121/5000][49/51]	Loss_D: 1.3865	Loss_G: 0.6941	Real Score: 0.4994	 Fake Scores: 0.4995 / 0.4995
# Iteration :  6200
# [123/5000][49/51]	Loss_D: 1.3865	Loss_G: 0.6944	Real Score: 0.4993	 Fake Scores: 0.4994 / 0.4994
# Iteration :  6300
# [125/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6946	Real Score: 0.4992	 Fake Scores: 0.4993 / 0.4993
# Iteration :  6400
# [127/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6947	Real Score: 0.4992	 Fake Scores: 0.4992 / 0.4992
# Iteration :  6500
# [129/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6948	Real Score: 0.4991	 Fake Scores: 0.4992 / 0.4992
# Iteration :  6600
# [131/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6949	Real Score: 0.4991	 Fake Scores: 0.4991 / 0.4991
# Iteration :  6700
# [133/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6949	Real Score: 0.4991	 Fake Scores: 0.4991 / 0.4991
# Iteration :  6800
# [135/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6949	Real Score: 0.4991	 Fake Scores: 0.4991 / 0.4991
# Iteration :  6900
# [137/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6949	Real Score: 0.4991	 Fake Scores: 0.4991 / 0.4991
# Iteration :  7000
# [139/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6949	Real Score: 0.4991	 Fake Scores: 0.4991 / 0.4991
# Iteration :  7100
# [141/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6948	Real Score: 0.4991	 Fake Scores: 0.4992 / 0.4992
# Iteration :  7200
# [143/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6948	Real Score: 0.4991	 Fake Scores: 0.4992 / 0.4992
# Iteration :  7300
# [145/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6947	Real Score: 0.4992	 Fake Scores: 0.4992 / 0.4992
# Iteration :  7400
# [147/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6947	Real Score: 0.4992	 Fake Scores: 0.4992 / 0.4992
# Iteration :  7500
# [149/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6946	Real Score: 0.4992	 Fake Scores: 0.4993 / 0.4993
# Iteration :  7600
# [151/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6946	Real Score: 0.4993	 Fake Scores: 0.4993 / 0.4993
# Iteration :  7700
# [153/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6945	Real Score: 0.4993	 Fake Scores: 0.4993 / 0.4993
# Iteration :  7800
# [155/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6945	Real Score: 0.4993	 Fake Scores: 0.4993 / 0.4993
# Iteration :  7900
# [157/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6944	Real Score: 0.4993	 Fake Scores: 0.4994 / 0.4994
# Iteration :  8000
# [159/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6944	Real Score: 0.4993	 Fake Scores: 0.4994 / 0.4994
# Iteration :  8100
# [161/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6943	Real Score: 0.4994	 Fake Scores: 0.4994 / 0.4994
# Iteration :  8200
# [163/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6943	Real Score: 0.4994	 Fake Scores: 0.4994 / 0.4994
# Iteration :  8300
# [165/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6943	Real Score: 0.4994	 Fake Scores: 0.4994 / 0.4994
# Iteration :  8400
# [167/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6942	Real Score: 0.4994	 Fake Scores: 0.4995 / 0.4995
# Iteration :  8500
# [169/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6942	Real Score: 0.4995	 Fake Scores: 0.4995 / 0.4995
# Iteration :  8600
# [171/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6941	Real Score: 0.4995	 Fake Scores: 0.4995 / 0.4995
# Iteration :  8700
# [173/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6941	Real Score: 0.4995	 Fake Scores: 0.4995 / 0.4995
# Iteration :  8800
# [175/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6941	Real Score: 0.4995	 Fake Scores: 0.4995 / 0.4995
# Iteration :  8900
# [177/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6940	Real Score: 0.4995	 Fake Scores: 0.4996 / 0.4996
# Iteration :  9000
# [179/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6940	Real Score: 0.4996	 Fake Scores: 0.4996 / 0.4996
# Iteration :  9100
# [181/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6939	Real Score: 0.4996	 Fake Scores: 0.4996 / 0.4996
# Iteration :  9200
# [183/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6939	Real Score: 0.4996	 Fake Scores: 0.4996 / 0.4996
# Iteration :  9300
# [185/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6939	Real Score: 0.4996	 Fake Scores: 0.4996 / 0.4996
# Iteration :  9400
# [187/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6938	Real Score: 0.4996	 Fake Scores: 0.4997 / 0.4997
# Iteration :  9500
# [189/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6937	Real Score: 0.4997	 Fake Scores: 0.4997 / 0.4997
# Iteration :  9600
# [191/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6937	Real Score: 0.4997	 Fake Scores: 0.4997 / 0.4997
# Iteration :  9700
# [193/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6936	Real Score: 0.4997	 Fake Scores: 0.4998 / 0.4998
# Iteration :  9800
# [195/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6935	Real Score: 0.4998	 Fake Scores: 0.4998 / 0.4998
# Iteration :  9900
# [197/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6935	Real Score: 0.4998	 Fake Scores: 0.4998 / 0.4998
# Iteration :  10000
# [199/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6935	Real Score: 0.4998	 Fake Scores: 0.4998 / 0.4998
# Iteration :  10100
# [201/5000][49/51]	Loss_D: 1.3865	Loss_G: 0.6942	Real Score: 0.4995	 Fake Scores: 0.4995 / 0.4994
# Iteration :  10200
# [203/5000][49/51]	Loss_D: 1.4255	Loss_G: 0.6036	Real Score: 0.5319	 Fake Scores: 0.5472 / 0.5468
# Iteration :  10300
# [205/5000][49/51]	Loss_D: 1.3973	Loss_G: 0.6391	Real Score: 0.5240	 Fake Scores: 0.5279 / 0.5278
# Iteration :  10400
# [207/5000][49/51]	Loss_D: 1.3910	Loss_G: 0.6522	Real Score: 0.5195	 Fake Scores: 0.5210 / 0.5209
# Iteration :  10500
# [209/5000][49/51]	Loss_D: 1.3887	Loss_G: 0.6603	Real Score: 0.5161	 Fake Scores: 0.5168 / 0.5167
# Iteration :  10600
# [211/5000][49/51]	Loss_D: 1.3878	Loss_G: 0.6664	Real Score: 0.5132	 Fake Scores: 0.5136 / 0.5136
# Iteration :  10700
# [213/5000][49/51]	Loss_D: 1.3874	Loss_G: 0.6712	Real Score: 0.5108	 Fake Scores: 0.5111 / 0.5111
# Iteration :  10800
# [215/5000][49/51]	Loss_D: 1.3871	Loss_G: 0.6751	Real Score: 0.5089	 Fake Scores: 0.5091 / 0.5091
# Iteration :  10900
# [217/5000][49/51]	Loss_D: 1.3869	Loss_G: 0.6784	Real Score: 0.5073	 Fake Scores: 0.5075 / 0.5074
# Iteration :  11000
# [219/5000][49/51]	Loss_D: 1.3867	Loss_G: 0.6811	Real Score: 0.5060	 Fake Scores: 0.5061 / 0.5061
# Iteration :  11100
# [221/5000][49/51]	Loss_D: 1.3867	Loss_G: 0.6833	Real Score: 0.5048	 Fake Scores: 0.5050 / 0.5049
# Iteration :  11200
# [223/5000][49/51]	Loss_D: 1.3866	Loss_G: 0.6852	Real Score: 0.5039	 Fake Scores: 0.5040 / 0.5040
# Iteration :  11300
# [225/5000][49/51]	Loss_D: 1.3865	Loss_G: 0.6868	Real Score: 0.5031	 Fake Scores: 0.5032 / 0.5032
# Iteration :  11400
# [227/5000][49/51]	Loss_D: 1.3865	Loss_G: 0.6881	Real Score: 0.5024	 Fake Scores: 0.5025 / 0.5025
# Iteration :  11500
# [229/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6892	Real Score: 0.5019	 Fake Scores: 0.5020 / 0.5020
# Iteration :  11600
# [231/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6902	Real Score: 0.5014	 Fake Scores: 0.5015 / 0.5015
# Iteration :  11700
# [233/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6909	Real Score: 0.5011	 Fake Scores: 0.5011 / 0.5011
# Iteration :  11800
# [235/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6915	Real Score: 0.5008	 Fake Scores: 0.5008 / 0.5008
# Iteration :  11900
# [237/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6920	Real Score: 0.5005	 Fake Scores: 0.5006 / 0.5006
# Iteration :  12000
# [239/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6924	Real Score: 0.5003	 Fake Scores: 0.5004 / 0.5004
# Iteration :  12100
# [241/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6927	Real Score: 0.5002	 Fake Scores: 0.5002 / 0.5002
# Iteration :  12200
# [243/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6929	Real Score: 0.5001	 Fake Scores: 0.5001 / 0.5001
# Iteration :  12300
# [245/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  12400
# [247/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6932	Real Score: 0.4999	 Fake Scores: 0.5000 / 0.5000
# Iteration :  12500
# [249/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6933	Real Score: 0.4999	 Fake Scores: 0.4999 / 0.4999
# Saved generator at /content/drive/My Drive/c147_project/Models/CNN-CNN/Generator_250.pth
# Iteration :  12600
# [251/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6934	Real Score: 0.4999	 Fake Scores: 0.4999 / 0.4999
# Iteration :  12700
# [253/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6934	Real Score: 0.4999	 Fake Scores: 0.4999 / 0.4999
# Iteration :  12800
# [255/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6934	Real Score: 0.4998	 Fake Scores: 0.4999 / 0.4999
# Iteration :  12900
# [257/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6934	Real Score: 0.4998	 Fake Scores: 0.4999 / 0.4999
# Iteration :  13000
# [259/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6934	Real Score: 0.4999	 Fake Scores: 0.4999 / 0.4999
# Iteration :  13100
# [261/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6934	Real Score: 0.4999	 Fake Scores: 0.4999 / 0.4999
# Iteration :  13200
# [263/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6933	Real Score: 0.4999	 Fake Scores: 0.4999 / 0.4999
# Iteration :  13300
# [265/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6934	Real Score: 0.4999	 Fake Scores: 0.4999 / 0.4999
# Iteration :  13400
# [267/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6933	Real Score: 0.4999	 Fake Scores: 0.4999 / 0.4999
# Iteration :  13500
# [269/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6933	Real Score: 0.4999	 Fake Scores: 0.4999 / 0.4999
# Iteration :  13600
# [271/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6933	Real Score: 0.4999	 Fake Scores: 0.4999 / 0.4999
# Iteration :  13700
# [273/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6933	Real Score: 0.4999	 Fake Scores: 0.4999 / 0.4999
# Iteration :  13800
# [275/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6933	Real Score: 0.4999	 Fake Scores: 0.4999 / 0.4999
# Iteration :  13900
# [277/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6933	Real Score: 0.4999	 Fake Scores: 0.4999 / 0.4999
# Iteration :  14000
# [279/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6933	Real Score: 0.4999	 Fake Scores: 0.4999 / 0.4999
# Iteration :  14100
# [281/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6933	Real Score: 0.4999	 Fake Scores: 0.4999 / 0.4999
# Iteration :  14200
# [283/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6933	Real Score: 0.4999	 Fake Scores: 0.4999 / 0.4999
# Iteration :  14300
# [285/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6933	Real Score: 0.4999	 Fake Scores: 0.4999 / 0.4999
# Iteration :  14400
# [287/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6933	Real Score: 0.4999	 Fake Scores: 0.4999 / 0.4999
# Iteration :  14500
# [289/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6933	Real Score: 0.4999	 Fake Scores: 0.4999 / 0.4999
# Iteration :  14600
# [291/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6933	Real Score: 0.4999	 Fake Scores: 0.4999 / 0.4999
# Iteration :  14700
# [293/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6933	Real Score: 0.4999	 Fake Scores: 0.4999 / 0.4999
# Iteration :  14800
# [295/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6933	Real Score: 0.4999	 Fake Scores: 0.4999 / 0.4999
# Iteration :  14900
# [297/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6933	Real Score: 0.4999	 Fake Scores: 0.4999 / 0.4999
# Iteration :  15000
# [299/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6933	Real Score: 0.4999	 Fake Scores: 0.4999 / 0.4999
# Iteration :  15100
# [301/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.4999	 Fake Scores: 0.4999 / 0.4999
# Iteration :  15200
# [303/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.4999	 Fake Scores: 0.5000 / 0.5000
# Iteration :  15300
# [305/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  15400
# [307/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  15500
# [309/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  15600
# [311/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  15700
# [313/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  15800
# [315/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  15900
# [317/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  16000
# [319/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  16100
# [321/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  16200
# [323/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  16300
# [325/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  16400
# [327/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  16500
# [329/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  16600
# [331/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  16700
# [333/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  16800
# [335/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  16900
# [337/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  17000
# [339/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  17100
# [341/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  17200
# [343/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  17300
# [345/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  17400
# [347/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  17500
# [349/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  17600
# [351/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  17700
# [353/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  17800
# [355/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  17900
# [357/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  18000
# [359/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  18100
# [361/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  18200
# [363/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  18300
# [365/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  18400
# [367/5000][49/51]	Loss_D: 1.3861	Loss_G: 0.6934	Real Score: 0.5000	 Fake Scores: 0.4999 / 0.4999
# Iteration :  18500
# [369/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6937	Real Score: 0.4997	 Fake Scores: 0.4997 / 0.4997
# Iteration :  18600
# [371/5000][49/51]	Loss_D: 1.4068	Loss_G: 0.6550	Real Score: 0.5107	 Fake Scores: 0.5198 / 0.5194
# Iteration :  18700
# [373/5000][49/51]	Loss_D: 1.3378	Loss_G: 0.6855	Real Score: 0.5296	 Fake Scores: 0.5039 / 0.5038
# Iteration :  18800
# [375/5000][49/51]	Loss_D: 1.4004	Loss_G: 0.5951	Real Score: 0.5500	 Fake Scores: 0.5517 / 0.5515
# Iteration :  18900
# [377/5000][49/51]	Loss_D: 1.3947	Loss_G: 0.6145	Real Score: 0.5401	 Fake Scores: 0.5410 / 0.5409
# Iteration :  19000
# [379/5000][49/51]	Loss_D: 1.3921	Loss_G: 0.6286	Real Score: 0.5327	 Fake Scores: 0.5334 / 0.5333
# Iteration :  19100
# [381/5000][49/51]	Loss_D: 1.3903	Loss_G: 0.6393	Real Score: 0.5272	 Fake Scores: 0.5277 / 0.5277
# Iteration :  19200
# [383/5000][49/51]	Loss_D: 1.3894	Loss_G: 0.6478	Real Score: 0.5228	 Fake Scores: 0.5232 / 0.5232
# Iteration :  19300
# [385/5000][49/51]	Loss_D: 1.3887	Loss_G: 0.6548	Real Score: 0.5192	 Fake Scores: 0.5196 / 0.5196
# Iteration :  19400
# [387/5000][49/51]	Loss_D: 1.3880	Loss_G: 0.6606	Real Score: 0.5163	 Fake Scores: 0.5166 / 0.5166
# Iteration :  19500
# [389/5000][49/51]	Loss_D: 1.3877	Loss_G: 0.6654	Real Score: 0.5138	 Fake Scores: 0.5141 / 0.5141
# Iteration :  19600
# [391/5000][49/51]	Loss_D: 1.3875	Loss_G: 0.6696	Real Score: 0.5117	 Fake Scores: 0.5120 / 0.5119
# Iteration :  19700
# [393/5000][49/51]	Loss_D: 1.3872	Loss_G: 0.6731	Real Score: 0.5099	 Fake Scores: 0.5101 / 0.5101
# Iteration :  19800
# [395/5000][49/51]	Loss_D: 1.3871	Loss_G: 0.6761	Real Score: 0.5084	 Fake Scores: 0.5086 / 0.5086
# Iteration :  19900
# [397/5000][49/51]	Loss_D: 1.3869	Loss_G: 0.6787	Real Score: 0.5071	 Fake Scores: 0.5073 / 0.5073
# Iteration :  20000
# [399/5000][49/51]	Loss_D: 1.3868	Loss_G: 0.6809	Real Score: 0.5060	 Fake Scores: 0.5062 / 0.5061
# Iteration :  20100
# [401/5000][49/51]	Loss_D: 1.3868	Loss_G: 0.6828	Real Score: 0.5050	 Fake Scores: 0.5052 / 0.5052
# Iteration :  20200
# [403/5000][49/51]	Loss_D: 1.3867	Loss_G: 0.6845	Real Score: 0.5042	 Fake Scores: 0.5044 / 0.5044
# Iteration :  20300
# [405/5000][49/51]	Loss_D: 1.3866	Loss_G: 0.6859	Real Score: 0.5035	 Fake Scores: 0.5037 / 0.5036
# Iteration :  20400
# [407/5000][49/51]	Loss_D: 1.3866	Loss_G: 0.6871	Real Score: 0.5029	 Fake Scores: 0.5031 / 0.5031
# Iteration :  20500
# [409/5000][49/51]	Loss_D: 1.3866	Loss_G: 0.6881	Real Score: 0.5024	 Fake Scores: 0.5026 / 0.5025
# Iteration :  20600
# [411/5000][49/51]	Loss_D: 1.3865	Loss_G: 0.6889	Real Score: 0.5020	 Fake Scores: 0.5021 / 0.5021
# Iteration :  20700
# [413/5000][49/51]	Loss_D: 1.3865	Loss_G: 0.6896	Real Score: 0.5017	 Fake Scores: 0.5018 / 0.5018
# Iteration :  20800
# [415/5000][49/51]	Loss_D: 1.3865	Loss_G: 0.6902	Real Score: 0.5014	 Fake Scores: 0.5015 / 0.5015
# Iteration :  20900
# [417/5000][49/51]	Loss_D: 1.3865	Loss_G: 0.6907	Real Score: 0.5011	 Fake Scores: 0.5012 / 0.5012
# Iteration :  21000
# [419/5000][49/51]	Loss_D: 1.3865	Loss_G: 0.6911	Real Score: 0.5009	 Fake Scores: 0.5010 / 0.5010
# Iteration :  21100
# [421/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6915	Real Score: 0.5008	 Fake Scores: 0.5008 / 0.5008
# Iteration :  21200
# [423/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6917	Real Score: 0.5007	 Fake Scores: 0.5007 / 0.5007
# Iteration :  21300
# [425/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6920	Real Score: 0.5005	 Fake Scores: 0.5006 / 0.5006
# Iteration :  21400
# [427/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6922	Real Score: 0.5005	 Fake Scores: 0.5005 / 0.5005
# Iteration :  21500
# [429/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6923	Real Score: 0.5004	 Fake Scores: 0.5004 / 0.5004
# Iteration :  21600
# [431/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6924	Real Score: 0.5003	 Fake Scores: 0.5004 / 0.5004
# Iteration :  21700
# [433/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6925	Real Score: 0.5003	 Fake Scores: 0.5003 / 0.5003
# Iteration :  21800
# [435/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6926	Real Score: 0.5002	 Fake Scores: 0.5003 / 0.5003
# Iteration :  21900
# [437/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6927	Real Score: 0.5002	 Fake Scores: 0.5002 / 0.5002
# Iteration :  22000
# [439/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6928	Real Score: 0.5002	 Fake Scores: 0.5002 / 0.5002
# Iteration :  22100
# [441/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6928	Real Score: 0.5001	 Fake Scores: 0.5002 / 0.5002
# Iteration :  22200
# [443/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6929	Real Score: 0.5001	 Fake Scores: 0.5001 / 0.5001
# Iteration :  22300
# [445/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6929	Real Score: 0.5001	 Fake Scores: 0.5001 / 0.5001
# Iteration :  22400
# [447/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6930	Real Score: 0.5001	 Fake Scores: 0.5001 / 0.5001
# Iteration :  22500
# [449/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6930	Real Score: 0.5000	 Fake Scores: 0.5001 / 0.5001
# Iteration :  22600
# [451/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6930	Real Score: 0.5000	 Fake Scores: 0.5001 / 0.5001
# Iteration :  22700
# [453/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  22800
# [455/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  22900
# [457/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  23000
# [459/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  23100
# [461/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  23200
# [463/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  23300
# [465/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  23400
# [467/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  23500
# [469/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  23600
# [471/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  23700
# [473/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  23800
# [475/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  23900
# [477/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  24000
# [479/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  24100
# [481/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  24200
# [483/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  24300
# [485/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  24400
# [487/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  24500
# [489/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  24600
# [491/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  24700
# [493/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  24800
# [495/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  24900
# [497/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  25000
# [499/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Saved generator at /content/drive/My Drive/c147_project/Models/CNN-CNN/Generator_500.pth
# Iteration :  25100
# [501/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  25200
# [503/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  25300
# [505/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  25400
# [507/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  25500
# [509/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  25600
# [511/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  25700
# [513/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  25800
# [515/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  25900
# [517/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  26000
# [519/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  26100
# [521/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  26200
# [523/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  26300
# [525/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  26400
# [527/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  26500
# [529/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  26600
# [531/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  26700
# [533/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  26800
# [535/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  26900
# [537/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  27000
# [539/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  27100
# [541/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  27200
# [543/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  27300
# [545/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  27400
# [547/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  27500
# [549/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  27600
# [551/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  27700
# [553/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  27800
# [555/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  27900
# [557/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  28000
# [559/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  28100
# [561/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  28200
# [563/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  28300
# [565/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  28400
# [567/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  28500
# [569/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  28600
# [571/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  28700
# [573/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  28800
# [575/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  28900
# [577/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  29000
# [579/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  29100
# [581/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  29200
# [583/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  29300
# [585/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  29400
# [587/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  29500
# [589/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6926	Real Score: 0.5003	 Fake Scores: 0.5003 / 0.5003
# Iteration :  29600
# [591/5000][49/51]	Loss_D: 1.3866	Loss_G: 0.6943	Real Score: 0.4993	 Fake Scores: 0.4995 / 0.4994
# Iteration :  29700
# [593/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.4999	 Fake Scores: 0.5000 / 0.5000
# Iteration :  29800
# [595/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  29900
# [597/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  30000
# [599/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  30100
# [601/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  30200
# [603/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  30300
# [605/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  30400
# [607/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  30500
# [609/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  30600
# [611/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  30700
# [613/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  30800
# [615/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  30900
# [617/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  31000
# [619/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  31100
# [621/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  31200
# [623/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  31300
# [625/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  31400
# [627/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  31500
# [629/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  31600
# [631/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  31700
# [633/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  31800
# [635/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  31900
# [637/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  32000
# [639/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  32100
# [641/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  32200
# [643/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  32300
# [645/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  32400
# [647/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  32500
# [649/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  32600
# [651/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  32700
# [653/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  32800
# [655/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  32900
# [657/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  33000
# [659/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  33100
# [661/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  33200
# [663/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  33300
# [665/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  33400
# [667/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  33500
# [669/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  33600
# [671/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  33700
# [673/5000][49/51]	Loss_D: 1.3425	Loss_G: 0.7186	Real Score: 0.5100	 Fake Scores: 0.4878 / 0.4874
# Iteration :  33800
# [675/5000][49/51]	Loss_D: 1.3898	Loss_G: 0.6493	Real Score: 0.5218	 Fake Scores: 0.5225 / 0.5224
# Iteration :  33900
# [677/5000][49/51]	Loss_D: 1.3882	Loss_G: 0.6567	Real Score: 0.5183	 Fake Scores: 0.5186 / 0.5186
# Iteration :  34000
# [679/5000][49/51]	Loss_D: 1.3876	Loss_G: 0.6626	Real Score: 0.5154	 Fake Scores: 0.5155 / 0.5155
# Iteration :  34100
# [681/5000][49/51]	Loss_D: 1.3872	Loss_G: 0.6676	Real Score: 0.5129	 Fake Scores: 0.5130 / 0.5130
# Iteration :  34200
# [683/5000][49/51]	Loss_D: 1.3869	Loss_G: 0.6717	Real Score: 0.5108	 Fake Scores: 0.5108 / 0.5108
# Iteration :  34300
# [685/5000][49/51]	Loss_D: 1.3868	Loss_G: 0.6752	Real Score: 0.5090	 Fake Scores: 0.5090 / 0.5090
# Iteration :  34400
# [687/5000][49/51]	Loss_D: 1.3867	Loss_G: 0.6782	Real Score: 0.5075	 Fake Scores: 0.5075 / 0.5075
# Iteration :  34500
# [689/5000][49/51]	Loss_D: 1.3866	Loss_G: 0.6808	Real Score: 0.5062	 Fake Scores: 0.5062 / 0.5062
# Iteration :  34600
# [691/5000][49/51]	Loss_D: 1.3865	Loss_G: 0.6829	Real Score: 0.5051	 Fake Scores: 0.5052 / 0.5052
# Iteration :  34700
# [693/5000][49/51]	Loss_D: 1.3865	Loss_G: 0.6847	Real Score: 0.5042	 Fake Scores: 0.5043 / 0.5043
# Iteration :  34800
# [695/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6862	Real Score: 0.5035	 Fake Scores: 0.5035 / 0.5035
# Iteration :  34900
# [697/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6875	Real Score: 0.5028	 Fake Scores: 0.5029 / 0.5029
# Iteration :  35000
# [699/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6885	Real Score: 0.5023	 Fake Scores: 0.5023 / 0.5023
# Iteration :  35100
# [701/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6894	Real Score: 0.5019	 Fake Scores: 0.5019 / 0.5019
# Iteration :  35200
# [703/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6901	Real Score: 0.5015	 Fake Scores: 0.5015 / 0.5015
# Iteration :  35300
# [705/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6907	Real Score: 0.5012	 Fake Scores: 0.5012 / 0.5012
# Iteration :  35400
# [707/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6912	Real Score: 0.5010	 Fake Scores: 0.5010 / 0.5010
# Iteration :  35500
# [709/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6915	Real Score: 0.5008	 Fake Scores: 0.5008 / 0.5008
# Iteration :  35600
# [711/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6919	Real Score: 0.5006	 Fake Scores: 0.5007 / 0.5006
# Iteration :  35700
# [713/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6921	Real Score: 0.5005	 Fake Scores: 0.5005 / 0.5005
# Iteration :  35800
# [715/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6923	Real Score: 0.5004	 Fake Scores: 0.5004 / 0.5004
# Iteration :  35900
# [717/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6925	Real Score: 0.5003	 Fake Scores: 0.5003 / 0.5003
# Iteration :  36000
# [719/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6926	Real Score: 0.5003	 Fake Scores: 0.5003 / 0.5003
# Iteration :  36100
# [721/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6927	Real Score: 0.5002	 Fake Scores: 0.5002 / 0.5002
# Iteration :  36200
# [723/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6928	Real Score: 0.5002	 Fake Scores: 0.5002 / 0.5002
# Iteration :  36300
# [725/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6928	Real Score: 0.5001	 Fake Scores: 0.5002 / 0.5001
# Iteration :  36400
# [727/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6929	Real Score: 0.5001	 Fake Scores: 0.5001 / 0.5001
# Iteration :  36500
# [729/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6930	Real Score: 0.5001	 Fake Scores: 0.5001 / 0.5001
# Iteration :  36600
# [731/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6930	Real Score: 0.5001	 Fake Scores: 0.5001 / 0.5001
# Iteration :  36700
# [733/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6930	Real Score: 0.5001	 Fake Scores: 0.5001 / 0.5001
# Iteration :  36800
# [735/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6930	Real Score: 0.5000	 Fake Scores: 0.5001 / 0.5001
# Iteration :  36900
# [737/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  37000
# [739/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  37100
# [741/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  37200
# [743/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  37300
# [745/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  37400
# [747/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  37500
# [749/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Saved generator at /content/drive/My Drive/c147_project/Models/CNN-CNN/Generator_750.pth
# Iteration :  37600
# [751/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  37700
# [753/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  37800
# [755/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  37900
# [757/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  38000
# [759/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  38100
# [761/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  38200
# [763/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  38300
# [765/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  38400
# [767/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  38500
# [769/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  38600
# [771/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  38700
# [773/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  38800
# [775/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  38900
# [777/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  39000
# [779/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  39100
# [781/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  39200
# [783/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  39300
# [785/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  39400
# [787/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  39500
# [789/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  39600
# [791/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  39700
# [793/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  39800
# [795/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  39900
# [797/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  40000
# [799/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  40100
# [801/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  40200
# [803/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  40300
# [805/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  40400
# [807/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  40500
# [809/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  40600
# [811/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  40700
# [813/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  40800
# [815/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  40900
# [817/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  41000
# [819/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  41100
# [821/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  41200
# [823/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  41300
# [825/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  41400
# [827/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  41500
# [829/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  41600
# [831/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  41700
# [833/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  41800
# [835/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  41900
# [837/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  42000
# [839/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  42100
# [841/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  42200
# [843/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  42300
# ...
# Iteration :  236700
# [4733/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  236800
# [4735/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  236900
# [4737/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  237000
# [4739/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  237100
# [4741/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  237200
# [4743/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  237300
# [4745/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  237400
# [4747/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  237500
# [4749/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Saved generator at /content/drive/My Drive/c147_project/Models/CNN-CNN/Generator_4750.pth
# Iteration :  237600
# [4751/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  237700
# [4753/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  237800
# [4755/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  237900
# [4757/5000][49/51]	Loss_D: 1.3862	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  238000
# [4759/5000][49/51]	Loss_D: 1.3823	Loss_G: 0.6932	Real Score: 0.5021	 Fake Scores: 0.5001 / 0.5000
# Iteration :  238100
# [4761/5000][49/51]	Loss_D: 1.3841	Loss_G: 0.6816	Real Score: 0.5074	 Fake Scores: 0.5062 / 0.5058
# Iteration :  238200
# [4763/5000][49/51]	Loss_D: 0.9665	Loss_G: 0.7407	Real Score: 0.7522	 Fake Scores: 0.4917 / 0.4768
# Iteration :  238300
# [4765/5000][49/51]	Loss_D: 0.6083	Loss_G: 1.2941	Real Score: 0.7680	 Fake Scores: 0.2858 / 0.2742
# Iteration :  238400
# [4767/5000][49/51]	Loss_D: 1.4065	Loss_G: 0.6156	Real Score: 0.6938	 Fake Scores: 0.6377 / 0.5403
# Iteration :  238500
# [4769/5000][49/51]	Loss_D: 0.7937	Loss_G: 0.9691	Real Score: 0.7937	 Fake Scores: 0.4230 / 0.3794
# Iteration :  238600
# [4771/5000][49/51]	Loss_D: 0.8558	Loss_G: 0.8606	Real Score: 0.7780	 Fake Scores: 0.4481 / 0.4229
# Iteration :  238700
# [4773/5000][49/51]	Loss_D: 1.2132	Loss_G: 0.8111	Real Score: 0.5536	 Fake Scores: 0.4492 / 0.4444
# Iteration :  238800
# [4775/5000][49/51]	Loss_D: 0.5719	Loss_G: 1.2702	Real Score: 0.8179	 Fake Scores: 0.2998 / 0.2808
# Iteration :  238900
# [4777/5000][49/51]	Loss_D: 0.7555	Loss_G: 1.5411	Real Score: 0.6604	 Fake Scores: 0.2374 / 0.2142
# Iteration :  239000
# [4779/5000][49/51]	Loss_D: 0.4006	Loss_G: 2.4531	Real Score: 0.7380	 Fake Scores: 0.0891 / 0.0860
# Iteration :  239100
# [4781/5000][49/51]	Loss_D: 0.3953	Loss_G: 2.0786	Real Score: 0.7897	 Fake Scores: 0.1283 / 0.1251
# Iteration :  239200
# [4783/5000][49/51]	Loss_D: 2.2271	Loss_G: 0.4116	Real Score: 0.4976	 Fake Scores: 0.7450 / 0.6629
# Iteration :  239300
# [4785/5000][49/51]	Loss_D: 1.5250	Loss_G: 0.6261	Real Score: 0.4817	 Fake Scores: 0.5392 / 0.5347
# Iteration :  239400
# [4787/5000][49/51]	Loss_D: 1.5398	Loss_G: 0.5700	Real Score: 0.5012	 Fake Scores: 0.5665 / 0.5655
# Iteration :  239500
# [4789/5000][49/51]	Loss_D: 1.7133	Loss_G: 0.4646	Real Score: 0.4900	 Fake Scores: 0.6305 / 0.6284
# Iteration :  239600
# [4791/5000][49/51]	Loss_D: 1.5966	Loss_G: 0.5496	Real Score: 0.4812	 Fake Scores: 0.5782 / 0.5772
# Iteration :  239700
# [4793/5000][49/51]	Loss_D: 1.5275	Loss_G: 0.5924	Real Score: 0.4871	 Fake Scores: 0.5536 / 0.5530
# Iteration :  239800
# [4795/5000][49/51]	Loss_D: 1.4757	Loss_G: 0.6335	Real Score: 0.4882	 Fake Scores: 0.5311 / 0.5307
# Iteration :  239900
# [4797/5000][49/51]	Loss_D: 1.4713	Loss_G: 0.6350	Real Score: 0.4893	 Fake Scores: 0.5301 / 0.5299
# Iteration :  240000
# [4799/5000][49/51]	Loss_D: 1.4820	Loss_G: 0.6339	Real Score: 0.4848	 Fake Scores: 0.5309 / 0.5305
# Iteration :  240100
# [4801/5000][49/51]	Loss_D: 1.4490	Loss_G: 0.6624	Real Score: 0.4856	 Fake Scores: 0.5160 / 0.5156
# Iteration :  240200
# [4803/5000][49/51]	Loss_D: 1.4154	Loss_G: 0.6964	Real Score: 0.4848	 Fake Scores: 0.4987 / 0.4984
# Iteration :  240300
# [4805/5000][49/51]	Loss_D: 1.3995	Loss_G: 0.7058	Real Score: 0.4877	 Fake Scores: 0.4936 / 0.4937
# Iteration :  240400
# [4807/5000][49/51]	Loss_D: 1.4448	Loss_G: 0.6502	Real Score: 0.4940	 Fake Scores: 0.5224 / 0.5220
# Iteration :  240500
# [4809/5000][49/51]	Loss_D: 1.4194	Loss_G: 0.6717	Real Score: 0.4949	 Fake Scores: 0.5110 / 0.5108
# Iteration :  240600
# [4811/5000][49/51]	Loss_D: 1.4273	Loss_G: 0.6647	Real Score: 0.4946	 Fake Scores: 0.5147 / 0.5144
# Iteration :  240700
# [4813/5000][49/51]	Loss_D: 1.4261	Loss_G: 0.6672	Real Score: 0.4939	 Fake Scores: 0.5134 / 0.5131
# Iteration :  240800
# [4815/5000][49/51]	Loss_D: 1.4284	Loss_G: 0.6601	Real Score: 0.4966	 Fake Scores: 0.5171 / 0.5168
# Iteration :  240900
# [4817/5000][49/51]	Loss_D: 1.4388	Loss_G: 0.6531	Real Score: 0.4950	 Fake Scores: 0.5206 / 0.5204
# Iteration :  241000
# [4819/5000][49/51]	Loss_D: 1.4290	Loss_G: 0.6641	Real Score: 0.4939	 Fake Scores: 0.5149 / 0.5147
# Iteration :  241100
# [4821/5000][49/51]	Loss_D: 1.4173	Loss_G: 0.6736	Real Score: 0.4947	 Fake Scores: 0.5100 / 0.5099
# Iteration :  241200
# [4823/5000][49/51]	Loss_D: 1.4130	Loss_G: 0.6758	Real Score: 0.4956	 Fake Scores: 0.5088 / 0.5088
# Iteration :  241300
# [4825/5000][49/51]	Loss_D: 1.4071	Loss_G: 0.6800	Real Score: 0.4964	 Fake Scores: 0.5067 / 0.5066
# Iteration :  241400
# [4827/5000][49/51]	Loss_D: 1.4045	Loss_G: 0.6823	Real Score: 0.4965	 Fake Scores: 0.5055 / 0.5055
# Iteration :  241500
# [4829/5000][49/51]	Loss_D: 1.4024	Loss_G: 0.6838	Real Score: 0.4968	 Fake Scores: 0.5047 / 0.5047
# Iteration :  241600
# [4831/5000][49/51]	Loss_D: 1.4018	Loss_G: 0.6840	Real Score: 0.4969	 Fake Scores: 0.5046 / 0.5046
# Iteration :  241700
# [4833/5000][49/51]	Loss_D: 1.4036	Loss_G: 0.6824	Real Score: 0.4969	 Fake Scores: 0.5054 / 0.5054
# Iteration :  241800
# [4835/5000][49/51]	Loss_D: 1.4014	Loss_G: 0.6849	Real Score: 0.4967	 Fake Scores: 0.5042 / 0.5041
# Iteration :  241900
# [4837/5000][49/51]	Loss_D: 1.3983	Loss_G: 0.6878	Real Score: 0.4967	 Fake Scores: 0.5027 / 0.5027
# Iteration :  242000
# [4839/5000][49/51]	Loss_D: 1.3970	Loss_G: 0.6873	Real Score: 0.4976	 Fake Scores: 0.5029 / 0.5029
# Iteration :  242100
# [4841/5000][49/51]	Loss_D: 1.3969	Loss_G: 0.6855	Real Score: 0.4986	 Fake Scores: 0.5039 / 0.5039
# Iteration :  242200
# [4843/5000][49/51]	Loss_D: 1.3977	Loss_G: 0.6848	Real Score: 0.4986	 Fake Scores: 0.5043 / 0.5042
# Iteration :  242300
# [4845/5000][49/51]	Loss_D: 1.3971	Loss_G: 0.6862	Real Score: 0.4982	 Fake Scores: 0.5035 / 0.5035
# Iteration :  242400
# [4847/5000][49/51]	Loss_D: 1.3960	Loss_G: 0.6873	Real Score: 0.4981	 Fake Scores: 0.5029 / 0.5029
# Iteration :  242500
# [4849/5000][49/51]	Loss_D: 1.3949	Loss_G: 0.6899	Real Score: 0.4974	 Fake Scores: 0.5016 / 0.5016
# Iteration :  242600
# [4851/5000][49/51]	Loss_D: 1.3967	Loss_G: 0.6879	Real Score: 0.4975	 Fake Scores: 0.5027 / 0.5026
# Iteration :  242700
# [4853/5000][49/51]	Loss_D: 1.3950	Loss_G: 0.6902	Real Score: 0.4972	 Fake Scores: 0.5015 / 0.5015
# Iteration :  242800
# [4855/5000][49/51]	Loss_D: 1.3961	Loss_G: 0.6881	Real Score: 0.4977	 Fake Scores: 0.5025 / 0.5025
# Iteration :  242900
# [4857/5000][49/51]	Loss_D: 1.3944	Loss_G: 0.6896	Real Score: 0.4978	 Fake Scores: 0.5018 / 0.5018
# Iteration :  243000
# [4859/5000][49/51]	Loss_D: 1.3933	Loss_G: 0.6902	Real Score: 0.4980	 Fake Scores: 0.5015 / 0.5015
# Iteration :  243100
# [4861/5000][49/51]	Loss_D: 1.3930	Loss_G: 0.6892	Real Score: 0.4987	 Fake Scores: 0.5020 / 0.5020
# Iteration :  243200
# [4863/5000][49/51]	Loss_D: 1.3914	Loss_G: 0.6899	Real Score: 0.4992	 Fake Scores: 0.5017 / 0.5016
# Iteration :  243300
# [4865/5000][49/51]	Loss_D: 1.3895	Loss_G: 0.6915	Real Score: 0.4994	 Fake Scores: 0.5010 / 0.5008
# Iteration :  243400
# [4867/5000][49/51]	Loss_D: 1.3912	Loss_G: 0.6908	Real Score: 0.4987	 Fake Scores: 0.5012 / 0.5012
# Iteration :  243500
# [4869/5000][49/51]	Loss_D: 1.3942	Loss_G: 0.6874	Real Score: 0.4991	 Fake Scores: 0.5031 / 0.5029
# Iteration :  243600
# [4871/5000][49/51]	Loss_D: 1.3908	Loss_G: 0.6907	Real Score: 0.4991	 Fake Scores: 0.5013 / 0.5012
# Iteration :  243700
# [4873/5000][49/51]	Loss_D: 1.3878	Loss_G: 0.6936	Real Score: 0.4992	 Fake Scores: 0.4999 / 0.4998
# Iteration :  243800
# [4875/5000][49/51]	Loss_D: 1.3902	Loss_G: 0.6905	Real Score: 0.4994	 Fake Scores: 0.5014 / 0.5013
# Iteration :  243900
# [4877/5000][49/51]	Loss_D: 1.3910	Loss_G: 0.6898	Real Score: 0.4994	 Fake Scores: 0.5017 / 0.5017
# Iteration :  244000
# [4879/5000][49/51]	Loss_D: 1.3932	Loss_G: 0.6878	Real Score: 0.4993	 Fake Scores: 0.5028 / 0.5027
# Iteration :  244100
# [4881/5000][49/51]	Loss_D: 1.3802	Loss_G: 0.7000	Real Score: 0.4998	 Fake Scores: 0.4967 / 0.4966
# Iteration :  244200
# [4883/5000][49/51]	Loss_D: 1.3901	Loss_G: 0.6914	Real Score: 0.4991	 Fake Scores: 0.5010 / 0.5009
# Iteration :  244300
# [4885/5000][49/51]	Loss_D: 1.3901	Loss_G: 0.6927	Real Score: 0.4984	 Fake Scores: 0.5003 / 0.5002
# Iteration :  244400
# [4887/5000][49/51]	Loss_D: 1.3871	Loss_G: 0.6942	Real Score: 0.4992	 Fake Scores: 0.4996 / 0.4995
# Iteration :  244500
# [4889/5000][49/51]	Loss_D: 1.3939	Loss_G: 0.6876	Real Score: 0.4991	 Fake Scores: 0.5029 / 0.5028
# Iteration :  244600
# [4891/5000][49/51]	Loss_D: 1.3886	Loss_G: 0.6922	Real Score: 0.4994	 Fake Scores: 0.5005 / 0.5005
# Iteration :  244700
# [4893/5000][49/51]	Loss_D: 1.3897	Loss_G: 0.6914	Real Score: 0.4993	 Fake Scores: 0.5010 / 0.5009
# Iteration :  244800
# [4895/5000][49/51]	Loss_D: 1.3874	Loss_G: 0.6927	Real Score: 0.4997	 Fake Scores: 0.5002 / 0.5002
# Iteration :  244900
# [4897/5000][49/51]	Loss_D: 1.3884	Loss_G: 0.6918	Real Score: 0.4996	 Fake Scores: 0.5007 / 0.5007
# Iteration :  245000
# [4899/5000][49/51]	Loss_D: 1.3878	Loss_G: 0.6927	Real Score: 0.4995	 Fake Scores: 0.5002 / 0.5002
# Iteration :  245100
# [4901/5000][49/51]	Loss_D: 1.3890	Loss_G: 0.6918	Real Score: 0.4994	 Fake Scores: 0.5007 / 0.5007
# Iteration :  245200
# [4903/5000][49/51]	Loss_D: 1.3890	Loss_G: 0.6915	Real Score: 0.4995	 Fake Scores: 0.5008 / 0.5008
# Iteration :  245300
# [4905/5000][49/51]	Loss_D: 1.3891	Loss_G: 0.6920	Real Score: 0.4992	 Fake Scores: 0.5006 / 0.5006
# Iteration :  245400
# [4907/5000][49/51]	Loss_D: 1.3889	Loss_G: 0.6918	Real Score: 0.4994	 Fake Scores: 0.5007 / 0.5007
# Iteration :  245500
# [4909/5000][49/51]	Loss_D: 1.3887	Loss_G: 0.6923	Real Score: 0.4993	 Fake Scores: 0.5005 / 0.5004
# Iteration :  245600
# [4911/5000][49/51]	Loss_D: 1.3889	Loss_G: 0.6913	Real Score: 0.4997	 Fake Scores: 0.5010 / 0.5009
# Iteration :  245700
# [4913/5000][49/51]	Loss_D: 1.3885	Loss_G: 0.6919	Real Score: 0.4995	 Fake Scores: 0.5006 / 0.5006
# Iteration :  245800
# [4915/5000][49/51]	Loss_D: 1.3867	Loss_G: 0.6929	Real Score: 0.5000	 Fake Scores: 0.5002 / 0.5001
# Iteration :  245900
# [4917/5000][49/51]	Loss_D: 1.3861	Loss_G: 0.6940	Real Score: 0.4997	 Fake Scores: 0.4996 / 0.4996
# Iteration :  246000
# [4919/5000][49/51]	Loss_D: 1.3852	Loss_G: 0.6941	Real Score: 0.5002	 Fake Scores: 0.4996 / 0.4995
# Iteration :  246100
# [4921/5000][49/51]	Loss_D: 1.3859	Loss_G: 0.6942	Real Score: 0.4997	 Fake Scores: 0.4995 / 0.4995
# Iteration :  246200
# [4923/5000][49/51]	Loss_D: 1.3893	Loss_G: 0.6909	Real Score: 0.4997	 Fake Scores: 0.5012 / 0.5011
# Iteration :  246300
# [4925/5000][49/51]	Loss_D: 1.3892	Loss_G: 0.6920	Real Score: 0.4992	 Fake Scores: 0.5006 / 0.5006
# Iteration :  246400
# [4927/5000][49/51]	Loss_D: 1.3885	Loss_G: 0.6923	Real Score: 0.4994	 Fake Scores: 0.5005 / 0.5004
# Iteration :  246500
# [4929/5000][49/51]	Loss_D: 1.3878	Loss_G: 0.6920	Real Score: 0.4999	 Fake Scores: 0.5006 / 0.5006
# Iteration :  246600
# [4931/5000][49/51]	Loss_D: 1.3878	Loss_G: 0.6924	Real Score: 0.4997	 Fake Scores: 0.5004 / 0.5004
# Iteration :  246700
# [4933/5000][49/51]	Loss_D: 1.3879	Loss_G: 0.6928	Real Score: 0.4994	 Fake Scores: 0.5002 / 0.5002
# Iteration :  246800
# [4935/5000][49/51]	Loss_D: 1.3872	Loss_G: 0.6930	Real Score: 0.4996	 Fake Scores: 0.5001 / 0.5001
# Iteration :  246900
# [4937/5000][49/51]	Loss_D: 1.3870	Loss_G: 0.6929	Real Score: 0.4998	 Fake Scores: 0.5001 / 0.5001
# Iteration :  247000
# [4939/5000][49/51]	Loss_D: 1.3867	Loss_G: 0.6932	Real Score: 0.4998	 Fake Scores: 0.5000 / 0.5000
# Iteration :  247100
# [4941/5000][49/51]	Loss_D: 1.3878	Loss_G: 0.6919	Real Score: 0.4999	 Fake Scores: 0.5007 / 0.5006
# Iteration :  247200
# [4943/5000][49/51]	Loss_D: 1.3881	Loss_G: 0.6926	Real Score: 0.4994	 Fake Scores: 0.5003 / 0.5003
# Iteration :  247300
# [4945/5000][49/51]	Loss_D: 1.3881	Loss_G: 0.6922	Real Score: 0.4997	 Fake Scores: 0.5005 / 0.5005
# Iteration :  247400
# [4947/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6935	Real Score: 0.4998	 Fake Scores: 0.4998 / 0.4998
# Iteration :  247500
# [4949/5000][49/51]	Loss_D: 1.3867	Loss_G: 0.6928	Real Score: 0.5000	 Fake Scores: 0.5002 / 0.5002
# Iteration :  247600
# [4951/5000][49/51]	Loss_D: 1.3875	Loss_G: 0.6927	Real Score: 0.4996	 Fake Scores: 0.5002 / 0.5002
# Iteration :  247700
# [4953/5000][49/51]	Loss_D: 1.3880	Loss_G: 0.6925	Real Score: 0.4995	 Fake Scores: 0.5003 / 0.5003
# Iteration :  247800
# [4955/5000][49/51]	Loss_D: 1.3878	Loss_G: 0.6922	Real Score: 0.4997	 Fake Scores: 0.5005 / 0.5005
# Iteration :  247900
# [4957/5000][49/51]	Loss_D: 1.3872	Loss_G: 0.6925	Real Score: 0.4999	 Fake Scores: 0.5003 / 0.5003
# Iteration :  248000
# [4959/5000][49/51]	Loss_D: 1.3878	Loss_G: 0.6925	Real Score: 0.4996	 Fake Scores: 0.5004 / 0.5003
# Iteration :  248100
# [4961/5000][49/51]	Loss_D: 1.3870	Loss_G: 0.6929	Real Score: 0.4998	 Fake Scores: 0.5002 / 0.5001
# Iteration :  248200
# [4963/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6931	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  248300
# [4965/5000][49/51]	Loss_D: 1.3864	Loss_G: 0.6932	Real Score: 0.5000	 Fake Scores: 0.5000 / 0.5000
# Iteration :  248400
# [4967/5000][49/51]	Loss_D: 1.3863	Loss_G: 0.6934	Real Score: 0.4998	 Fake Scores: 0.4998 / 0.4999
# Iteration :  248500
# [4969/5000][49/51]	Loss_D: 1.3862	Loss_G: 0.6923	Real Score: 0.5004	 Fake Scores: 0.5004 / 0.5004
# Iteration :  248600
# [4971/5000][49/51]	Loss_D: 1.3870	Loss_G: 0.6927	Real Score: 0.4999	 Fake Scores: 0.5003 / 0.5002
# Iteration :  248700
# [4973/5000][49/51]	Loss_D: 1.3866	Loss_G: 0.6936	Real Score: 0.4997	 Fake Scores: 0.4998 / 0.4998
# Iteration :  248800
# [4975/5000][49/51]	Loss_D: 1.3856	Loss_G: 0.6935	Real Score: 0.5002	 Fake Scores: 0.4998 / 0.4998
# Iteration :  248900
# [4977/5000][49/51]	Loss_D: 1.3851	Loss_G: 0.6939	Real Score: 0.5002	 Fake Scores: 0.4997 / 0.4996
# Iteration :  249000
# [4979/5000][49/51]	Loss_D: 1.3854	Loss_G: 0.6939	Real Score: 0.5002	 Fake Scores: 0.4997 / 0.4996
# Iteration :  249100
# [4981/5000][49/51]	Loss_D: 1.3870	Loss_G: 0.6927	Real Score: 0.4999	 Fake Scores: 0.5003 / 0.5002
# Iteration :  249200
# [4983/5000][49/51]	Loss_D: 1.3867	Loss_G: 0.6935	Real Score: 0.4996	 Fake Scores: 0.4998 / 0.4998
# Iteration :  249300
# [4985/5000][49/51]	Loss_D: 1.3873	Loss_G: 0.6927	Real Score: 0.4998	 Fake Scores: 0.5003 / 0.5002
# Iteration :  249400
# [4987/5000][49/51]	Loss_D: 1.3867	Loss_G: 0.6925	Real Score: 0.5002	 Fake Scores: 0.5004 / 0.5003
# Iteration :  249500
# [4989/5000][49/51]	Loss_D: 1.3875	Loss_G: 0.6923	Real Score: 0.4999	 Fake Scores: 0.5005 / 0.5004
# Iteration :  249600
# [4991/5000][49/51]	Loss_D: 1.3868	Loss_G: 0.6931	Real Score: 0.4998	 Fake Scores: 0.5000 / 0.5000
# Iteration :  249700
# [4993/5000][49/51]	Loss_D: 1.3871	Loss_G: 0.6927	Real Score: 0.4999	 Fake Scores: 0.5003 / 0.5002
# Iteration :  249800
# [4995/5000][49/51]	Loss_D: 1.3862	Loss_G: 0.6936	Real Score: 0.4998	 Fake Scores: 0.4998 / 0.4998
# Iteration :  249900
# [4997/5000][49/51]	Loss_D: 1.3873	Loss_G: 0.6923	Real Score: 0.4999	 Fake Scores: 0.5004 / 0.5004
# Iteration :  250000
# [4999/5000][49/51]	Loss_D: 1.3867	Loss_G: 0.6928	Real Score: 0.5000	 Fake Scores: 0.5002 / 0.5002
# Saved generator at /content/drive/My Drive/c147_project/Models/CNN-CNN/Generator_5000.pth

# %%
plt.plot(gan.G_loss, label='Generator Loss')
plt.plot(gan.D_loss, label='Discriminator Loss')
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.legend()
plt.title("CNN-CNN GAN loss diagram")
# Out:
# Text(0.5, 1.0, 'CNN-CNN GAN loss diagram')

# %%
plt.plot(gan.generated_test[-1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-e587672ddc04> in <module>()
# ----> 1 plt.plot(gan.generated_test[-1])
#
# AttributeError: 'GAN' object has no attribute 'generated_test'

# %%
import torchinfo
batch = 250
Gtest = Gen
Gtest.to(device)
print(torchinfo.summary(Gtest, input_size=(250, 100, 1)))

Dtest = dis
Dtest.to(device)
print(torchinfo.summary(Dtest, input_size=(250, 22, 100)))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Sequential: 1-1                        [250, 220, 4]             --
# |    └─ConvTranspose1d: 2-1              [250, 220, 4]             88,000
# |    └─BatchNorm1d: 2-2                  [250, 220, 4]             440
# |    └─ReLU: 2-3                         [250, 220, 4]             --
# ├─Sequential: 1-2                        [250, 154, 10]            --
# |    └─ConvTranspose1d: 2-4              [250, 154, 10]            135,520
# |    └─BatchNorm1d: 2-5                  [250, 154, 10]            308
# |    └─ReLU: 2-6                         [250, 154, 10]            --
# ├─Sequential: 1-3                        [250, 88, 22]             --
# |    └─ConvTranspose1d: 2-7              [250, 88, 22]             54,208
# |    └─BatchNorm1d: 2-8                  [250, 88, 22]             176
# |    └─ReLU: 2-9                         [250, 88, 22]             --
# ├─Sequential: 1-4                        [250, 44, 49]             --
# |    └─ConvTranspose1d: 2-10             [250, 44, 49]             27,104
# |    └─BatchNorm1d: 2-11                 [250, 44, 49]             88
# |    └─ReLU: 2-12                        [250, 44, 49]             --
# ├─Sequential: 1-5                        [250, 22, 100]            --
# |    └─ConvTranspose1d: 2-13             [250, 22, 100]            3,872
# |    └─Tanh: 2-14                        [250, 22, 100]            --
# ==========================================================================================
# Total params: 309,716
# Trainable params: 309,716
# Non-trainable params: 0
# Total mult-adds (M): 4.92
# ==========================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 30.45
# Params size (MB): 1.24
# Estimated Total Size (MB): 31.79
# ==========================================================================================
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Sequential: 1-1                        [250, 18, 50]             --
# |    └─Conv1d: 2-1                       [250, 18, 50]             1,188
# |    └─LeakyReLU: 2-2                    [250, 18, 50]             --
# ├─Sequential: 1-2                        [250, 14, 25]             --
# |    └─Conv1d: 2-3                       [250, 14, 25]             756
# |    └─BatchNorm1d: 2-4                  [250, 14, 25]             28
# |    └─LeakyReLU: 2-5                    [250, 14, 25]             --
# ├─Sequential: 1-3                        [250, 10, 13]             --
# |    └─Conv1d: 2-6                       [250, 10, 13]             420
# |    └─BatchNorm1d: 2-7                  [250, 10, 13]             20
# |    └─LeakyReLU: 2-8                    [250, 10, 13]             --
# ├─Sequential: 1-4                        [250, 6, 7]               --
# |    └─Conv1d: 2-9                       [250, 6, 7]               180
# |    └─BatchNorm1d: 2-10                 [250, 6, 7]               12
# |    └─LeakyReLU: 2-11                   [250, 6, 7]               --
# ├─Sequential: 1-5                        [250, 1, 1]               --
# |    └─Conv1d: 2-12                      [250, 1, 4]               18
# |    └─BatchNorm1d: 2-13                 [250, 1, 4]               2
# |    └─LeakyReLU: 2-14                   [250, 1, 4]               --
# |    └─Conv1d: 2-15                      [250, 1, 1]               4
# |    └─Sigmoid: 2-16                     [250, 1, 1]               --
# ==========================================================================================
# Total params: 2,628
# Trainable params: 2,628
# Non-trainable params: 0
# Total mult-adds (M): 0.09
# ==========================================================================================
# Input size (MB): 2.20
# Forward/backward pass size (MB): 3.91
# Params size (MB): 0.01
# Estimated Total Size (MB): 6.12
# ==========================================================================================
