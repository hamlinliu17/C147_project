# %% [markdown]
# # LSTM- LSTM notebook
# This notebook was used to run the GAN where the generator was an LSTM and the discriminator was also an LSTM

# %%
import os
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
os.chdir('/content/drive/My Drive/c147_project/')

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import os
import time
from data import eegData
import numpy as np
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
# get the device type of machine
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
train_dataset = eegData('data/X_train_valid.npy', 'data/y_train_valid.npy', device, preprocessing_params={'trim':400, 'subsample': 6})

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import os
import time
import numpy as np
import matplotlib.pyplot as plt

def count_parameters(model):
  """Function for count model's parameters"""
  return sum(p.numel() for p in model.parameters() if p.requires_grad)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# !pip install torchinfo
# Out:
# Collecting torchinfo
#   Downloading https://files.pythonhosted.org/packages/4f/b1/4b310bd715885636e7174b4b52817202fff0ae3609ca2bfb17f28e33e0a1/torchinfo-0.0.8-py3-none-any.whl
# Installing collected packages: torchinfo
# Successfully installed torchinfo-0.0.8

# %%
class Reshape(nn.Module):
  def __init__(self, shape):
    super(Reshape, self).__init__()
    self.shape = shape
  
  def forward(self, x):
    new_shape = [x.shape[0]] + list(self.shape)
    return x.view(new_shape)

class LSTMGenerator(nn.Module):
  """
  Generator that uses LSTM layer
  input is (batch, in_dim, seq)
  output is (batch, out_dim, seq)
  """
  def __init__(self, input_dim, hidden_dim, output_dim=22, n_layers=1, bias=False):
    super(LSTMGenerator, self).__init__()
    self.input_dim = input_dim
    self.out_dim = output_dim
    self.hidden_dim = hidden_dim
    self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers=n_layers, bias=bias, batch_first=True)

    self.linear = nn.Sequential(
        nn.Linear(hidden_dim, output_dim),
        nn.Tanh()
    )


  def forward(self, x):
    d1, d2, d3 = x.shape 
    x_reshaped = x.permute(0, 2, 1)
    recurrent, hidden = self.lstm(x_reshaped)
    out = self.linear(recurrent.contiguous().view(d1 * d3, self.hidden_dim))
    return out.view(d1, self.out_dim, d3)
  

class LSTMDiscriminator(nn.Module):
  """
  Discriminator that uses LSTM layer
  input is (batch, in_dim, seq)
  output is (batch, 1, seq)
  """
  def __init__(self, input_dim, hidden_dim, n_layers=1, bias=False):
    super(LSTMDiscriminator, self).__init__()
    self.input_dim = input_dim
    self.hidden_dim = hidden_dim
    self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers=n_layers, bias=bias, batch_first=True)
    self.linear = nn.Sequential(
        nn.Linear(hidden_dim, 1),
        nn.Sigmoid()
    )


  def forward(self, x):
    d1, d2, d3 = x.shape 
    x_reshaped = x.permute(0, 2, 1)
    recurrent, hidden = self.lstm(x_reshaped)
    out = self.linear(recurrent.contiguous().view(d1 * d3, self.hidden_dim))
    return out.view(d1, 1, d3)

# %%
class GAN(object):
  """
  Class object to control and abstract the training and logging of vanilla GANs
  Assumes that the noise input or z vector is (batch_size, 2, 600) 
    where the first channel is noise and the second channel is the label
  """
  def __init__(self,
               generator: nn.Module,
               discriminator: nn.Module,
               train_valid_data,
               **kwargs
               ):
    self.G = generator
    self.D = discriminator
    self.loss = nn.BCELoss()
    self.dataset = train_valid_data
    # checking for CUDA acceleration
    # move parameters to Cuda
    # establish before the optimizer and loss
    self.cuda_bool = kwargs.get('cuda', False)
    self.cuda_device = kwargs.get('device', 0)
    self.device = torch.device('cpu')
    if self.cuda_bool:
      print("Establishing network on CUDA device: ", torch.cuda.get_device_name(self.cuda_device))
      self.device = torch.device('cuda')
      self.G.cuda(self.cuda_device)
      self.D.cuda(self.cuda_device)
      self.loss.cuda(self.cuda_device)
    
    # setting up optimizers
    lr = kwargs.get('learn_rate', 0.0002)
    w_decay = kwargs.get('weight_decay', 0.00001)
    self.d_optimizer = torch.optim.Adam(self.D.parameters(), lr=lr, weight_decay=w_decay)
    self.g_optimizer = torch.optim.Adam(self.G.parameters(), lr=lr, weight_decay=w_decay)


  def train(self, 
            epochs, batch_size, save_path, verbose=True, print_every=100):
    
    
    self.epochs = epochs

    self.batch_size = batch_size

    self.G_loss = list()
    self.D_loss = list()
    self.generated_test = list()

    # setup the loader
    data_loader = torch.utils.data.DataLoader(self.dataset, batch_size=batch_size, shuffle=True)

    iteration = 0

    # TODO: change the input
    fixed_z = torch.rand((1, self.G.input_dim - 1, 100), device=self.device)
    fixed_labels = torch.zeros((1 , 1), device=self.device).reshape(-1, 1).repeat(1, 100).reshape(-1, 1, 100)
    fixed_z = torch.cat([fixed_z, fixed_labels], dim=1).to(self.device)
    real_label = 1
    fake_label = 0
    for epoch in range(self.epochs + 1):
      for i, sample in enumerate(data_loader):
        # What to do for each batch

        if i == data_loader.dataset.__len__() // self.batch_size:
          break

        self.G.train()

        # assert data and labels
        eeg_data = sample['data']
        eeg_labels = sample['label']

        # input vector for 
        noise = torch.rand((self.batch_size, self.G.input_dim - 1, 100), device=self.device)
        labels = eeg_labels.reshape(-1, 1).repeat(1, 100).reshape(-1, 1, 100)
        
        z = torch.cat([noise, labels], dim=1)

        seq_length = eeg_data.shape[2]

        benchmark = torch.full((self.batch_size, 1, seq_length), real_label, device=self.device, dtype=torch.float)

        # attach to cuda
        if self.cuda_bool:
          eeg_data = Variable(eeg_data.cuda(self.cuda_device))
          z = Variable(z.cuda(self.cuda_device))
        else:
          eeg_data = Variable(eeg_data)
          z = Variable(z)
        

        ##############
        # Training the Discriminator
        ##############
        self.d_optimizer.zero_grad()
        self.D.zero_grad() # remove previous gradients
        # train the discriminator on real data
        real_score = self.D(eeg_data)
        d_loss_real = self.loss(real_score, benchmark)
        d_loss_real.backward()
        real_output_score = real_score.mean().item()

        # train the discriminator on fake data

        benchmark.fill_(fake_label)
        fake_data = self.G(z)
        fake_score = self.D(fake_data.detach())
        d_loss_fake = self.loss(fake_score, benchmark)
        d_loss_fake.backward()
        # print(fake_score)
        G_output_score1 = fake_score.mean().item()
        

        # optimize the discriminator
        d_loss = d_loss_real + d_loss_fake
        self.d_optimizer.step()


        ##############
        # Training the Generator
        ##############
        self.G.zero_grad() # remove previous gradients
        self.g_optimizer.zero_grad()

        benchmark.fill_(real_label)
        fake_score2 = self.D(fake_data)
        G_output_score2 = fake_score2.mean().item()
        g_loss = self.loss(fake_score2, benchmark)
        g_loss.backward()
        self.g_optimizer.step()

        iteration += 1
        
        if iteration % print_every == 0 and verbose:
          # output the loss and the scores
          print("Iteration : ", iteration)
          print('[%d/%d][%d/%d]\tLoss_D: %.4f\tLoss_G: %.4f\tReal Score: %.4f\t Fake Scores: %.4f / %.4f'
                  % (epoch, self.epochs, i, len(data_loader),
                     d_loss.item(), g_loss.item(), real_output_score, G_output_score1, G_output_score2))
          
        self.G_loss.append(g_loss.cpu().item())
        self.D_loss.append(d_loss.cpu().item())

      # check how the Generator is doing
      with torch.no_grad() :
        self.G.eval()
        fake_data = self.G(fixed_z).detach().cpu()
        self.generated_test.append(np.mean(fake_data.numpy(), axis=(0, 1)))


      if epoch % 500 == 0:
        save_str = save_path + '/Generator_' + str(epoch) + '.pth'
        self.save_models(save_str)


  def save_models(self, path):
    torch.save(self.G.state_dict(), path)
    print("Saved generator at " + path)
    return True

# %%
Gtest = LSTMGenerator(2, 44)
Dtest = LSTMDiscriminator(22, 44)
# toy_GAN = GAN(Gtest, Dtest, train_dataset, cuda=True)

# %%
toy_GAN.train(5000, 250, save_path='/content/drive/My Drive/c147_project/Models/LSTM-LSTM')
# Out:
# Streaming output truncated to the last 5000 lines.
# Iteration :  500
# [9/5000][49/51]	Loss_D: 0.6128	Loss_G: 0.8232	Real Score: 0.9675	 Fake Scores: 0.4392 / 0.4391
# Iteration :  600
# [11/5000][49/51]	Loss_D: 0.5809	Loss_G: 0.8625	Real Score: 0.9721	 Fake Scores: 0.4235 / 0.4221
# Iteration :  700
# [13/5000][49/51]	Loss_D: 0.6574	Loss_G: 0.7899	Real Score: 0.9567	 Fake Scores: 0.4565 / 0.4540
# Iteration :  800
# [15/5000][49/51]	Loss_D: 0.4821	Loss_G: 1.0342	Real Score: 0.9628	 Fake Scores: 0.3567 / 0.3556
# Iteration :  900
# [17/5000][49/51]	Loss_D: 0.4718	Loss_G: 1.0451	Real Score: 0.9700	 Fake Scores: 0.3544 / 0.3520
# Iteration :  1000
# [19/5000][49/51]	Loss_D: 0.5376	Loss_G: 0.9080	Real Score: 0.9818	 Fake Scores: 0.4036 / 0.4035
# Iteration :  1100
# [21/5000][49/51]	Loss_D: 0.5241	Loss_G: 0.9203	Real Score: 0.9860	 Fake Scores: 0.3986 / 0.3985
# Iteration :  1200
# [23/5000][49/51]	Loss_D: 0.5184	Loss_G: 0.9272	Real Score: 0.9871	 Fake Scores: 0.3958 / 0.3957
# Iteration :  1300
# [25/5000][49/51]	Loss_D: 0.5107	Loss_G: 0.9374	Real Score: 0.9880	 Fake Scores: 0.3917 / 0.3917
# Iteration :  1400
# [27/5000][49/51]	Loss_D: 0.5041	Loss_G: 0.9453	Real Score: 0.9892	 Fake Scores: 0.3887 / 0.3886
# Iteration :  1500
# [29/5000][49/51]	Loss_D: 0.4960	Loss_G: 0.9568	Real Score: 0.9900	 Fake Scores: 0.3842 / 0.3841
# Iteration :  1600
# [31/5000][49/51]	Loss_D: 0.4832	Loss_G: 0.9768	Real Score: 0.9907	 Fake Scores: 0.3768 / 0.3765
# Iteration :  1700
# [33/5000][49/51]	Loss_D: 0.4852	Loss_G: 0.9729	Real Score: 0.9910	 Fake Scores: 0.3782 / 0.3780
# Iteration :  1800
# [35/5000][49/51]	Loss_D: 0.4660	Loss_G: 1.0038	Real Score: 0.9916	 Fake Scores: 0.3666 / 0.3665
# Iteration :  1900
# [37/5000][49/51]	Loss_D: 0.4584	Loss_G: 1.0165	Real Score: 0.9922	 Fake Scores: 0.3622 / 0.3619
# Iteration :  2000
# [39/5000][49/51]	Loss_D: 0.4597	Loss_G: 1.0130	Real Score: 0.9926	 Fake Scores: 0.3632 / 0.3632
# Iteration :  2100
# [41/5000][49/51]	Loss_D: 0.4476	Loss_G: 1.0341	Real Score: 0.9928	 Fake Scores: 0.3557 / 0.3555
# Iteration :  2200
# [43/5000][49/51]	Loss_D: 0.4371	Loss_G: 1.0529	Real Score: 0.9930	 Fake Scores: 0.3490 / 0.3489
# Iteration :  2300
# [45/5000][49/51]	Loss_D: 0.4165	Loss_G: 1.0960	Real Score: 0.9934	 Fake Scores: 0.3358 / 0.3343
# Iteration :  2400
# [47/5000][49/51]	Loss_D: 0.4407	Loss_G: 1.0447	Real Score: 0.9939	 Fake Scores: 0.3520 / 0.3519
# Iteration :  2500
# [49/5000][49/51]	Loss_D: 0.4106	Loss_G: 1.1030	Real Score: 0.9939	 Fake Scores: 0.3322 / 0.3319
# Iteration :  2600
# [51/5000][49/51]	Loss_D: 0.4121	Loss_G: 1.0995	Real Score: 0.9938	 Fake Scores: 0.3331 / 0.3331
# Iteration :  2700
# [53/5000][49/51]	Loss_D: 0.4270	Loss_G: 1.0710	Real Score: 0.9944	 Fake Scores: 0.3434 / 0.3427
# Iteration :  2800
# [55/5000][49/51]	Loss_D: 0.3900	Loss_G: 1.1437	Real Score: 0.9946	 Fake Scores: 0.3188 / 0.3187
# Iteration :  2900
# [57/5000][49/51]	Loss_D: 0.4094	Loss_G: 1.1039	Real Score: 0.9946	 Fake Scores: 0.3317 / 0.3316
# Iteration :  3000
# [59/5000][49/51]	Loss_D: 0.3543	Loss_G: 1.2273	Real Score: 0.9945	 Fake Scores: 0.2940 / 0.2932
# Iteration :  3100
# [61/5000][49/51]	Loss_D: 0.4116	Loss_G: 1.1019	Real Score: 0.9945	 Fake Scores: 0.3331 / 0.3327
# Iteration :  3200
# [63/5000][49/51]	Loss_D: 0.3765	Loss_G: 1.1725	Real Score: 0.9948	 Fake Scores: 0.3097 / 0.3096
# Iteration :  3300
# [65/5000][49/51]	Loss_D: 0.3693	Loss_G: 1.1888	Real Score: 0.9948	 Fake Scores: 0.3047 / 0.3046
# Iteration :  3400
# [67/5000][49/51]	Loss_D: 0.3678	Loss_G: 1.1914	Real Score: 0.9952	 Fake Scores: 0.3039 / 0.3038
# Iteration :  3500
# [69/5000][49/51]	Loss_D: 0.3583	Loss_G: 1.2123	Real Score: 0.9956	 Fake Scores: 0.2976 / 0.2975
# Iteration :  3600
# [71/5000][49/51]	Loss_D: 0.3576	Loss_G: 1.2139	Real Score: 0.9959	 Fake Scores: 0.2975 / 0.2970
# Iteration :  3700
# [73/5000][49/51]	Loss_D: 0.3480	Loss_G: 1.2352	Real Score: 0.9962	 Fake Scores: 0.2908 / 0.2908
# Iteration :  3800
# [75/5000][49/51]	Loss_D: 0.3486	Loss_G: 1.2334	Real Score: 0.9963	 Fake Scores: 0.2914 / 0.2913
# Iteration :  3900
# [77/5000][49/51]	Loss_D: 0.3371	Loss_G: 1.2625	Real Score: 0.9961	 Fake Scores: 0.2830 / 0.2830
# Iteration :  4000
# [79/5000][49/51]	Loss_D: 0.3327	Loss_G: 1.2738	Real Score: 0.9962	 Fake Scores: 0.2799 / 0.2798
# Iteration :  4100
# [81/5000][49/51]	Loss_D: 0.3283	Loss_G: 1.2848	Real Score: 0.9963	 Fake Scores: 0.2768 / 0.2767
# Iteration :  4200
# [83/5000][49/51]	Loss_D: 0.3223	Loss_G: 1.3013	Real Score: 0.9963	 Fake Scores: 0.2724 / 0.2722
# Iteration :  4300
# [85/5000][49/51]	Loss_D: 0.3203	Loss_G: 1.3054	Real Score: 0.9966	 Fake Scores: 0.2713 / 0.2711
# Iteration :  4400
# [87/5000][49/51]	Loss_D: 0.3117	Loss_G: 1.3273	Real Score: 0.9970	 Fake Scores: 0.2653 / 0.2652
# Iteration :  4500
# [89/5000][49/51]	Loss_D: 0.3084	Loss_G: 1.3372	Real Score: 0.9967	 Fake Scores: 0.2626 / 0.2626
# Iteration :  4600
# [91/5000][49/51]	Loss_D: 0.3058	Loss_G: 1.3426	Real Score: 0.9973	 Fake Scores: 0.2612 / 0.2612
# Iteration :  4700
# [93/5000][49/51]	Loss_D: 0.2954	Loss_G: 1.3740	Real Score: 0.9970	 Fake Scores: 0.2533 / 0.2531
# Iteration :  4800
# [95/5000][49/51]	Loss_D: 0.2926	Loss_G: 1.3823	Real Score: 0.9972	 Fake Scores: 0.2513 / 0.2510
# Iteration :  4900
# [97/5000][49/51]	Loss_D: 0.2941	Loss_G: 1.3771	Real Score: 0.9973	 Fake Scores: 0.2524 / 0.2524
# Iteration :  5000
# [99/5000][49/51]	Loss_D: 0.2783	Loss_G: 1.4252	Real Score: 0.9974	 Fake Scores: 0.2407 / 0.2405
# Iteration :  5100
# [101/5000][49/51]	Loss_D: 0.2873	Loss_G: 1.3955	Real Score: 0.9977	 Fake Scores: 0.2478 / 0.2477
# Iteration :  5200
# [103/5000][49/51]	Loss_D: 0.2692	Loss_G: 1.4524	Real Score: 0.9978	 Fake Scores: 0.2342 / 0.2340
# Iteration :  5300
# [105/5000][49/51]	Loss_D: 0.2774	Loss_G: 1.4260	Real Score: 0.9978	 Fake Scores: 0.2403 / 0.2403
# Iteration :  5400
# [107/5000][49/51]	Loss_D: 0.2622	Loss_G: 1.4754	Real Score: 0.9979	 Fake Scores: 0.2289 / 0.2287
# Iteration :  5500
# [109/5000][49/51]	Loss_D: 0.2693	Loss_G: 1.4530	Real Score: 0.9977	 Fake Scores: 0.2340 / 0.2339
# Iteration :  5600
# [111/5000][49/51]	Loss_D: 0.2555	Loss_G: 1.4980	Real Score: 0.9979	 Fake Scores: 0.2237 / 0.2236
# Iteration :  5700
# [113/5000][49/51]	Loss_D: 0.2594	Loss_G: 1.4846	Real Score: 0.9980	 Fake Scores: 0.2267 / 0.2266
# Iteration :  5800
# [115/5000][49/51]	Loss_D: 0.2507	Loss_G: 1.5144	Real Score: 0.9980	 Fake Scores: 0.2200 / 0.2199
# Iteration :  5900
# [117/5000][49/51]	Loss_D: 0.2511	Loss_G: 1.5138	Real Score: 0.9979	 Fake Scores: 0.2202 / 0.2201
# Iteration :  6000
# [119/5000][49/51]	Loss_D: 0.2462	Loss_G: 1.5305	Real Score: 0.9981	 Fake Scores: 0.2165 / 0.2164
# Iteration :  6100
# [121/5000][49/51]	Loss_D: 0.2398	Loss_G: 1.5535	Real Score: 0.9981	 Fake Scores: 0.2116 / 0.2115
# Iteration :  6200
# [123/5000][49/51]	Loss_D: 0.2373	Loss_G: 1.5635	Real Score: 0.9981	 Fake Scores: 0.2095 / 0.2094
# Iteration :  6300
# [125/5000][49/51]	Loss_D: 0.2342	Loss_G: 1.5741	Real Score: 0.9983	 Fake Scores: 0.2072 / 0.2072
# Iteration :  6400
# [127/5000][49/51]	Loss_D: 0.2290	Loss_G: 1.5927	Real Score: 0.9986	 Fake Scores: 0.2034 / 0.2034
# Iteration :  6500
# [129/5000][49/51]	Loss_D: 0.2255	Loss_G: 1.6067	Real Score: 0.9985	 Fake Scores: 0.2006 / 0.2005
# Iteration :  6600
# [131/5000][49/51]	Loss_D: 0.2232	Loss_G: 1.6153	Real Score: 0.9987	 Fake Scores: 0.1989 / 0.1988
# Iteration :  6700
# [133/5000][49/51]	Loss_D: 0.2197	Loss_G: 1.6300	Real Score: 0.9986	 Fake Scores: 0.1960 / 0.1959
# Iteration :  6800
# [135/5000][49/51]	Loss_D: 0.2157	Loss_G: 1.6463	Real Score: 0.9986	 Fake Scores: 0.1928 / 0.1928
# Iteration :  6900
# [137/5000][49/51]	Loss_D: 0.2127	Loss_G: 1.6579	Real Score: 0.9988	 Fake Scores: 0.1906 / 0.1905
# Iteration :  7000
# [139/5000][49/51]	Loss_D: 0.2092	Loss_G: 1.6738	Real Score: 0.9987	 Fake Scores: 0.1876 / 0.1875
# Iteration :  7100
# [141/5000][49/51]	Loss_D: 0.2060	Loss_G: 1.6872	Real Score: 0.9988	 Fake Scores: 0.1851 / 0.1850
# Iteration :  7200
# [143/5000][49/51]	Loss_D: 0.2023	Loss_G: 1.7032	Real Score: 0.9989	 Fake Scores: 0.1821 / 0.1821
# Iteration :  7300
# [145/5000][49/51]	Loss_D: 0.1989	Loss_G: 1.7184	Real Score: 0.9989	 Fake Scores: 0.1794 / 0.1794
# Iteration :  7400
# [225/5000][49/51]	Loss_D: 0.0138	Loss_G: 8.8825	Real Score: 0.9997	 Fake Scores: 0.0126 / 0.0126
# Iteration :  11400
# [227/5000][49/51]	Loss_D: 0.0074	Loss_G: 9.4652	Real Score: 0.9996	 Fake Scores: 0.0067 / 0.0067
# Iteration :  11500
# [229/5000][49/51]	Loss_D: 0.0146	Loss_G: 9.3612	Real Score: 0.9997	 Fake Scores: 0.0134 / 0.0133
# Iteration :  11600
# [231/5000][49/51]	Loss_D: 0.0169	Loss_G: 9.4862	Real Score: 0.9997	 Fake Scores: 0.0155 / 0.0154
# Iteration :  11700
# [233/5000][49/51]	Loss_D: 0.0172	Loss_G: 9.4142	Real Score: 0.9996	 Fake Scores: 0.0158 / 0.0157
# Iteration :  11800
# [235/5000][49/51]	Loss_D: 0.0145	Loss_G: 9.5273	Real Score: 0.9997	 Fake Scores: 0.0134 / 0.0134
# Iteration :  11900
# [237/5000][49/51]	Loss_D: 0.0125	Loss_G: 9.7031	Real Score: 0.9997	 Fake Scores: 0.0116 / 0.0116
# Iteration :  12000
# [239/5000][49/51]	Loss_D: 0.0118	Loss_G: 9.9182	Real Score: 0.9997	 Fake Scores: 0.0108 / 0.0108
# Iteration :  12100
# [241/5000][49/51]	Loss_D: 0.0219	Loss_G: 9.6934	Real Score: 0.9997	 Fake Scores: 0.0200 / 0.0200
# Iteration :  12200
# [243/5000][49/51]	Loss_D: 0.0087	Loss_G: 10.7699	Real Score: 0.9997	 Fake Scores: 0.0079 / 0.0079
# Iteration :  12300
# [245/5000][49/51]	Loss_D: 0.0080	Loss_G: 10.7010	Real Score: 0.9997	 Fake Scores: 0.0073 / 0.0073
# Iteration :  12400
# [247/5000][49/51]	Loss_D: 0.0075	Loss_G: 10.6336	Real Score: 0.9998	 Fake Scores: 0.0069 / 0.0069
# Iteration :  12500
# [249/5000][49/51]	Loss_D: 0.0072	Loss_G: 10.5715	Real Score: 0.9998	 Fake Scores: 0.0066 / 0.0066
# Iteration :  12600
# [251/5000][49/51]	Loss_D: 0.0069	Loss_G: 10.5323	Real Score: 0.9998	 Fake Scores: 0.0063 / 0.0063
# Iteration :  12700
# [253/5000][49/51]	Loss_D: 0.0066	Loss_G: 10.4940	Real Score: 0.9998	 Fake Scores: 0.0061 / 0.0061
# Iteration :  12800
# [255/5000][49/51]	Loss_D: 0.0065	Loss_G: 10.4510	Real Score: 0.9998	 Fake Scores: 0.0060 / 0.0060
# Iteration :  12900
# [257/5000][49/51]	Loss_D: 0.0065	Loss_G: 10.4039	Real Score: 0.9998	 Fake Scores: 0.0060 / 0.0060
# Iteration :  13000
# [259/5000][49/51]	Loss_D: 0.0068	Loss_G: 10.3371	Real Score: 0.9998	 Fake Scores: 0.0062 / 0.0062
# Iteration :  13100
# [261/5000][49/51]	Loss_D: 0.0081	Loss_G: 10.1015	Real Score: 0.9998	 Fake Scores: 0.0076 / 0.0076
# Iteration :  13200
# [263/5000][49/51]	Loss_D: 0.0070	Loss_G: 10.8490	Real Score: 0.9998	 Fake Scores: 0.0065 / 0.0065
# Iteration :  13300
# [265/5000][49/51]	Loss_D: 0.0066	Loss_G: 11.2054	Real Score: 0.9998	 Fake Scores: 0.0061 / 0.0061
# Iteration :  13400
# [267/5000][49/51]	Loss_D: 0.0062	Loss_G: 11.5286	Real Score: 0.9999	 Fake Scores: 0.0059 / 0.0059
# Iteration :  13500
# [269/5000][49/51]	Loss_D: 0.0060	Loss_G: 11.8428	Real Score: 0.9998	 Fake Scores: 0.0055 / 0.0055
# Iteration :  13600
# [271/5000][49/51]	Loss_D: 0.0058	Loss_G: 12.1280	Real Score: 0.9998	 Fake Scores: 0.0054 / 0.0054
# Iteration :  13700
# [273/5000][49/51]	Loss_D: 0.0059	Loss_G: 12.3776	Real Score: 0.9998	 Fake Scores: 0.0055 / 0.0055
# Iteration :  13800
# [275/5000][49/51]	Loss_D: 0.0058	Loss_G: 12.6432	Real Score: 0.9999	 Fake Scores: 0.0054 / 0.0054
# Iteration :  13900
# [277/5000][49/51]	Loss_D: 0.0062	Loss_G: 12.8471	Real Score: 0.9998	 Fake Scores: 0.0058 / 0.0058
# Iteration :  14000
# [279/5000][49/51]	Loss_D: 0.0144	Loss_G: 12.5485	Real Score: 0.9999	 Fake Scores: 0.0132 / 0.0129
# Iteration :  14100
# [281/5000][49/51]	Loss_D: 0.0033	Loss_G: 13.8222	Real Score: 0.9999	 Fake Scores: 0.0031 / 0.0031
# Iteration :  14200
# [283/5000][49/51]	Loss_D: 0.0033	Loss_G: 13.9980	Real Score: 0.9998	 Fake Scores: 0.0030 / 0.0030
# Iteration :  14300
# [285/5000][49/51]	Loss_D: 0.0032	Loss_G: 14.1824	Real Score: 0.9998	 Fake Scores: 0.0029 / 0.0029
# Iteration :  14400
# [287/5000][49/51]	Loss_D: 0.0032	Loss_G: 14.3602	Real Score: 0.9999	 Fake Scores: 0.0029 / 0.0029
# Iteration :  14500
# [289/5000][49/51]	Loss_D: 0.0031	Loss_G: 14.5416	Real Score: 0.9999	 Fake Scores: 0.0029 / 0.0029
# Iteration :  14600
# [291/5000][49/51]	Loss_D: 0.0030	Loss_G: 14.7285	Real Score: 0.9999	 Fake Scores: 0.0028 / 0.0028
# Iteration :  14700
# [293/5000][49/51]	Loss_D: 0.0030	Loss_G: 14.9165	Real Score: 0.9999	 Fake Scores: 0.0027 / 0.0027
# Iteration :  14800
# [295/5000][49/51]	Loss_D: 0.0029	Loss_G: 15.0925	Real Score: 0.9999	 Fake Scores: 0.0027 / 0.0027
# Iteration :  14900
# [297/5000][49/51]	Loss_D: 0.0030	Loss_G: 15.2745	Real Score: 0.9998	 Fake Scores: 0.0027 / 0.0027
# Iteration :  15000
# [299/5000][49/51]	Loss_D: 0.0028	Loss_G: 15.4694	Real Score: 0.9999	 Fake Scores: 0.0026 / 0.0026
# Iteration :  15100
# [301/5000][49/51]	Loss_D: 0.0028	Loss_G: 15.6565	Real Score: 0.9998	 Fake Scores: 0.0025 / 0.0025
# [341/5000][49/51]	Loss_D: 0.0019	Loss_G: 19.4943	Real Score: 0.9999	 Fake Scores: 0.0018 / 0.0018
# Iteration :  17200
# [343/5000][49/51]	Loss_D: 0.0019	Loss_G: 19.6849	Real Score: 0.9999	 Fake Scores: 0.0017 / 0.0017
# Iteration :  17300
# [345/5000][49/51]	Loss_D: 0.0019	Loss_G: 19.8607	Real Score: 0.9999	 Fake Scores: 0.0018 / 0.0018
# Iteration :  17400
# [347/5000][49/51]	Loss_D: 0.0019	Loss_G: 20.0555	Real Score: 0.9999	 Fake Scores: 0.0017 / 0.0017
# Iteration :  17500
# [349/5000][49/51]	Loss_D: 0.0018	Loss_G: 20.2478	Real Score: 0.9999	 Fake Scores: 0.0017 / 0.0017
# Iteration :  17600
# [351/5000][49/51]	Loss_D: 0.0018	Loss_G: 20.4510	Real Score: 0.9999	 Fake Scores: 0.0016 / 0.0016
# Iteration :  17700
# [353/5000][49/51]	Loss_D: 0.0018	Loss_G: 20.6168	Real Score: 0.9999	 Fake Scores: 0.0017 / 0.0017
# Iteration :  17800
# [355/5000][49/51]	Loss_D: 0.0019	Loss_G: 20.8170	Real Score: 0.9999	 Fake Scores: 0.0016 / 0.0016
# Iteration :  17900
# [357/5000][49/51]	Loss_D: 0.0019	Loss_G: 20.9762	Real Score: 0.9999	 Fake Scores: 0.0017 / 0.0017
# Iteration :  18000
# [359/5000][49/51]	Loss_D: 0.0017	Loss_G: 21.2088	Real Score: 1.0000	 Fake Scores: 0.0016 / 0.0016
# Iteration :  18100
# [361/5000][49/51]	Loss_D: 0.0018	Loss_G: 21.3561	Real Score: 1.0000	 Fake Scores: 0.0017 / 0.0017
# Iteration :  18200
# [363/5000][49/51]	Loss_D: 0.0018	Loss_G: 21.5430	Real Score: 1.0000	 Fake Scores: 0.0017 / 0.0017
# Iteration :  18300
# [365/5000][49/51]	Loss_D: 0.0019	Loss_G: 21.7641	Real Score: 0.9999	 Fake Scores: 0.0017 / 0.0017
# Iteration :  18400
# [367/5000][49/51]	Loss_D: 0.0020	Loss_G: 21.9305	Real Score: 0.9999	 Fake Scores: 0.0019 / 0.0019
# Iteration :  18500
# [369/5000][49/51]	Loss_D: 0.0052	Loss_G: 21.9165	Real Score: 1.0000	 Fake Scores: 0.0047 / 0.0047
# Iteration :  18600
# [371/5000][49/51]	Loss_D: 0.0037	Loss_G: 21.8091	Real Score: 0.9999	 Fake Scores: 0.0034 / 0.0034
# Iteration :  18700
# [373/5000][49/51]	Loss_D: 0.0041	Loss_G: 21.5463	Real Score: 1.0000	 Fake Scores: 0.0037 / 0.0037
# Iteration :  18800
# [375/5000][49/51]	Loss_D: 0.0063	Loss_G: 21.4247	Real Score: 0.9999	 Fake Scores: 0.0059 / 0.0059
# Iteration :  18900
# [377/5000][49/51]	Loss_D: 0.0056	Loss_G: 20.9506	Real Score: 0.9999	 Fake Scores: 0.0053 / 0.0052
# Iteration :  19000
# [379/5000][49/51]	Loss_D: 0.0048	Loss_G: 20.8185	Real Score: 0.9999	 Fake Scores: 0.0045 / 0.0044
# Iteration :  19100
# [381/5000][49/51]	Loss_D: 0.0034	Loss_G: 20.0481	Real Score: 0.9999	 Fake Scores: 0.0032 / 0.0031
# Iteration :  19200
# [383/5000][49/51]	Loss_D: 0.0027	Loss_G: 19.4197	Real Score: 0.9999	 Fake Scores: 0.0026 / 0.0026
# Iteration :  19300
# [385/5000][49/51]	Loss_D: 0.0024	Loss_G: 18.8923	Real Score: 0.9999	 Fake Scores: 0.0022 / 0.0022
# Iteration :  19400
# [387/5000][49/51]	Loss_D: 0.0022	Loss_G: 18.4140	Real Score: 0.9999	 Fake Scores: 0.0020 / 0.0020
# Iteration :  19500
# [389/5000][49/51]	Loss_D: 0.0019	Loss_G: 17.9566	Real Score: 1.0000	 Fake Scores: 0.0018 / 0.0018
# Iteration :  19600
# [391/5000][49/51]	Loss_D: 0.0018	Loss_G: 17.4700	Real Score: 0.9999	 Fake Scores: 0.0017 / 0.0016
# Iteration :  19700
# [393/5000][49/51]	Loss_D: 0.0018	Loss_G: 16.9271	Real Score: 0.9999	 Fake Scores: 0.0015 / 0.0015
# Iteration :  19800
# [395/5000][49/51]	Loss_D: 0.0015	Loss_G: 16.7617	Real Score: 0.9999	 Fake Scores: 0.0014 / 0.0014
# Iteration :  19900
# [397/5000][49/51]	Loss_D: 0.0014	Loss_G: 16.8771	Real Score: 0.9999	 Fake Scores: 0.0013 / 0.0013
# Iteration :  20000
# [399/5000][49/51]	Loss_D: 0.0013	Loss_G: 17.0094	Real Score: 1.0000	 Fake Scores: 0.0013 / 0.0013
# Iteration :  20100
# [401/5000][49/51]	Loss_D: 0.0013	Loss_G: 17.1421	Real Score: 0.9999	 Fake Scores: 0.0012 / 0.0012
# Iteration :  20200
# [403/5000][49/51]	Loss_D: 0.0012	Loss_G: 17.2813	Real Score: 0.9999	 Fake Scores: 0.0012 / 0.0012
# Iteration :  20300
# [405/5000][49/51]	Loss_D: 0.0012	Loss_G: 17.4193	Real Score: 1.0000	 Fake Scores: 0.0011 / 0.0011
# Iteration :  20400
# [407/5000][49/51]	Loss_D: 0.0012	Loss_G: 17.5463	Real Score: 0.9999	 Fake Scores: 0.0011 / 0.0011
# Iteration :  20500
# [409/5000][49/51]	Loss_D: 0.0011	Loss_G: 17.6794	Real Score: 1.0000	 Fake Scores: 0.0011 / 0.0011
# Iteration :  20600
# [411/5000][49/51]	Loss_D: 0.0011	Loss_G: 17.8147	Real Score: 1.0000	 Fake Scores: 0.0010 / 0.0010
# Iteration :  20700
# [413/5000][49/51]	Loss_D: 0.0011	Loss_G: 17.9333	Real Score: 0.9999	 Fake Scores: 0.0010 / 0.0010
# Iteration :  20800
# [415/5000][49/51]	Loss_D: 0.0012	Loss_G: 18.0569	Real Score: 0.9999	 Fake Scores: 0.0010 / 0.0010
# Iteration :  20900
# [417/5000][49/51]	Loss_D: 0.0011	Loss_G: 18.1821	Real Score: 0.9999	 Fake Scores: 0.0010 / 0.0010
# Iteration :  21000
# [419/5000][49/51]	Loss_D: 0.0010	Loss_G: 18.2879	Real Score: 1.0000	 Fake Scores: 0.0010 / 0.0010
# Iteration :  21100
# [421/5000][49/51]	Loss_D: 0.0010	Loss_G: 18.3988	Real Score: 1.0000	 Fake Scores: 0.0009 / 0.0009
# Iteration :  21200
# [423/5000][49/51]	Loss_D: 0.0010	Loss_G: 18.4873	Real Score: 0.9999	 Fake Scores: 0.0010 / 0.0010
# Iteration :  21300
# [425/5000][49/51]	Loss_D: 0.0011	Loss_G: 18.5907	Real Score: 0.9999	 Fake Scores: 0.0010 / 0.0010
# Iteration :  21400
# [427/5000][49/51]	Loss_D: 0.0049	Loss_G: 12.7673	Real Score: 1.0000	 Fake Scores: 0.0047 / 0.0047
# Iteration :  21500
# [429/5000][49/51]	Loss_D: 0.0033	Loss_G: 14.1278	Real Score: 0.9999	 Fake Scores: 0.0031 / 0.0031
# Iteration :  21600
# [431/5000][49/51]	Loss_D: 0.0032	Loss_G: 14.5646	Real Score: 1.0000	 Fake Scores: 0.0031 / 0.0031
# Iteration :  21700
# [433/5000][49/51]	Loss_D: 0.0029	Loss_G: 15.6304	Real Score: 0.9999	 Fake Scores: 0.0027 / 0.0027
# Iteration :  21800
# [435/5000][49/51]	Loss_D: 0.0027	Loss_G: 16.2182	Real Score: 1.0000	 Fake Scores: 0.0026 / 0.0026
# Iteration :  21900
# [437/5000][49/51]	Loss_D: 0.0015	Loss_G: 17.0362	Real Score: 1.0000	 Fake Scores: 0.0014 / 0.0014
# Iteration :  22000
# [439/5000][49/51]	Loss_D: 0.0015	Loss_G: 17.4457	Real Score: 0.9999	 Fake Scores: 0.0014 / 0.0014
# Iteration :  22100
# [441/5000][49/51]	Loss_D: 0.0015	Loss_G: 17.8154	Real Score: 1.0000	 Fake Scores: 0.0014 / 0.0014
# Iteration :  22200
# [443/5000][49/51]	Loss_D: 0.0015	Loss_G: 18.1394	Real Score: 1.0000	 Fake Scores: 0.0015 / 0.0015
# Iteration :  22300
# [445/5000][49/51]	Loss_D: 0.0017	Loss_G: 18.3895	Real Score: 1.0000	 Fake Scores: 0.0017 / 0.0017
# Iteration :  22400
# [447/5000][49/51]	Loss_D: 0.0016	Loss_G: 19.0591	Real Score: 0.9999	 Fake Scores: 0.0015 / 0.0015
# Iteration :  22500
# [449/5000][49/51]	Loss_D: 0.0018	Loss_G: 19.1389	Real Score: 1.0000	 Fake Scores: 0.0017 / 0.0017
# Iteration :  22600
# [451/5000][49/51]	Loss_D: 0.0019	Loss_G: 19.2151	Real Score: 0.9999	 Fake Scores: 0.0018 / 0.0018
# Iteration :  22700
# [453/5000][49/51]	Loss_D: 0.0016	Loss_G: 19.6856	Real Score: 1.0000	 Fake Scores: 0.0015 / 0.0015
# Iteration :  22800
# [455/5000][49/51]	Loss_D: 0.0021	Loss_G: 19.6534	Real Score: 1.0000	 Fake Scores: 0.0020 / 0.0020
# Iteration :  22900
# Iteration :  24900
# [497/5000][49/51]	Loss_D: 0.0011	Loss_G: 16.1845	Real Score: 0.9999	 Fake Scores: 0.0010 / 0.0010
# Iteration :  25000
# [499/5000][49/51]	Loss_D: 0.0010	Loss_G: 16.2474	Real Score: 0.9999	 Fake Scores: 0.0009 / 0.0009
# Saved generator at /content/drive/My Drive/c147_project/Models/LSTM-LSTM/Generator_500.pth
# Iteration :  25100
# [501/5000][49/51]	Loss_D: 0.0009	Loss_G: 16.3028	Real Score: 1.0000	 Fake Scores: 0.0009 / 0.0009
# Iteration :  25200
# [503/5000][49/51]	Loss_D: 0.0009	Loss_G: 16.3480	Real Score: 1.0000	 Fake Scores: 0.0008 / 0.0008
# Iteration :  25300
# [505/5000][49/51]	Loss_D: 0.0009	Loss_G: 16.3885	Real Score: 1.0000	 Fake Scores: 0.0008 / 0.0008
# Iteration :  25400
# [507/5000][49/51]	Loss_D: 0.0009	Loss_G: 16.4229	Real Score: 0.9999	 Fake Scores: 0.0008 / 0.0008
# Iteration :  25500
# [509/5000][49/51]	Loss_D: 0.0008	Loss_G: 16.4516	Real Score: 0.9999	 Fake Scores: 0.0008 / 0.0008
# Iteration :  25600
# [511/5000][49/51]	Loss_D: 0.0009	Loss_G: 16.4767	Real Score: 0.9999	 Fake Scores: 0.0008 / 0.0008
# Iteration :  25700
# [513/5000][49/51]	Loss_D: 0.0008	Loss_G: 16.4845	Real Score: 1.0000	 Fake Scores: 0.0008 / 0.0008
# Iteration :  25800
# [515/5000][49/51]	Loss_D: 0.0008	Loss_G: 16.4829	Real Score: 1.0000	 Fake Scores: 0.0008 / 0.0008
# Iteration :  25900
# [517/5000][49/51]	Loss_D: 0.0008	Loss_G: 16.4812	Real Score: 1.0000	 Fake Scores: 0.0007 / 0.0007
# Iteration :  26000
# [519/5000][49/51]	Loss_D: 0.0008	Loss_G: 16.4648	Real Score: 1.0000	 Fake Scores: 0.0007 / 0.0007
# Iteration :  26100
# [521/5000][49/51]	Loss_D: 0.0008	Loss_G: 16.4454	Real Score: 1.0000	 Fake Scores: 0.0007 / 0.0007
# Iteration :  26200
# [523/5000][49/51]	Loss_D: 0.0008	Loss_G: 16.4125	Real Score: 0.9999	 Fake Scores: 0.0007 / 0.0007
# Iteration :  26300
# [525/5000][49/51]	Loss_D: 0.0008	Loss_G: 16.3595	Real Score: 1.0000	 Fake Scores: 0.0007 / 0.0007
# Iteration :  26400
# [527/5000][49/51]	Loss_D: 0.0008	Loss_G: 16.3102	Real Score: 1.0000	 Fake Scores: 0.0007 / 0.0007
# Iteration :  26500
# [529/5000][49/51]	Loss_D: 0.0009	Loss_G: 16.2375	Real Score: 0.9999	 Fake Scores: 0.0007 / 0.0007
# Iteration :  26600
# [531/5000][49/51]	Loss_D: 0.0008	Loss_G: 16.1610	Real Score: 0.9999	 Fake Scores: 0.0007 / 0.0007
# Iteration :  26700
# [533/5000][49/51]	Loss_D: 0.0008	Loss_G: 16.0746	Real Score: 0.9999	 Fake Scores: 0.0007 / 0.0007
# Iteration :  26800
# [535/5000][49/51]	Loss_D: 0.0008	Loss_G: 15.9736	Real Score: 1.0000	 Fake Scores: 0.0007 / 0.0007
# Iteration :  26900
# [537/5000][49/51]	Loss_D: 0.0008	Loss_G: 15.8594	Real Score: 1.0000	 Fake Scores: 0.0008 / 0.0008
# Iteration :  27000
# [539/5000][49/51]	Loss_D: 0.0009	Loss_G: 15.7484	Real Score: 0.9999	 Fake Scores: 0.0008 / 0.0008
# Iteration :  27100
# [541/5000][49/51]	Loss_D: 0.0009	Loss_G: 15.6190	Real Score: 1.0000	 Fake Scores: 0.0008 / 0.0008
# Iteration :  27200
# [543/5000][49/51]	Loss_D: 0.0009	Loss_G: 15.4794	Real Score: 0.9999	 Fake Scores: 0.0008 / 0.0008
# Iteration :  27300
# [545/5000][49/51]	Loss_D: 0.0011	Loss_G: 15.2980	Real Score: 1.0000	 Fake Scores: 0.0010 / 0.0010
# Iteration :  27400
# [547/5000][49/51]	Loss_D: 0.0034	Loss_G: 11.9876	Real Score: 1.0000	 Fake Scores: 0.0033 / 0.0033
# Iteration :  27500
# [549/5000][49/51]	Loss_D: 0.0015	Loss_G: 16.0669	Real Score: 0.9999	 Fake Scores: 0.0014 / 0.0014
# Iteration :  27600
# [551/5000][49/51]	Loss_D: 0.0021	Loss_G: 13.0144	Real Score: 1.0000	 Fake Scores: 0.0020 / 0.0020
# Iteration :  27700
# [553/5000][49/51]	Loss_D: 0.0023	Loss_G: 13.8800	Real Score: 1.0000	 Fake Scores: 0.0022 / 0.0022
# Iteration :  27800
# [555/5000][49/51]	Loss_D: 0.0016	Loss_G: 14.4408	Real Score: 1.0000	 Fake Scores: 0.0015 / 0.0015
# Iteration :  27900
# [557/5000][49/51]	Loss_D: 0.0010	Loss_G: 14.9990	Real Score: 1.0000	 Fake Scores: 0.0010 / 0.0010
# Iteration :  28000
# [559/5000][49/51]	Loss_D: 0.0010	Loss_G: 15.2607	Real Score: 1.0000	 Fake Scores: 0.0009 / 0.0009
# Iteration :  28100
# [561/5000][49/51]	Loss_D: 0.0009	Loss_G: 15.4629	Real Score: 1.0000	 Fake Scores: 0.0009 / 0.0009
# Iteration :  28200
# [563/5000][49/51]	Loss_D: 0.0009	Loss_G: 15.6016	Real Score: 0.9999	 Fake Scores: 0.0009 / 0.0009
# Iteration :  28300
# [565/5000][49/51]	Loss_D: 0.0009	Loss_G: 15.7104	Real Score: 1.0000	 Fake Scores: 0.0008 / 0.0008
# Iteration :  28400
# [567/5000][49/51]	Loss_D: 0.0011	Loss_G: 15.3741	Real Score: 0.9999	 Fake Scores: 0.0010 / 0.0010
# Iteration :  28500
# [569/5000][49/51]	Loss_D: 0.0012	Loss_G: 14.9093	Real Score: 0.9999	 Fake Scores: 0.0011 / 0.0011
# Iteration :  28600
# [571/5000][49/51]	Loss_D: 0.0011	Loss_G: 14.9919	Real Score: 1.0000	 Fake Scores: 0.0011 / 0.0010
# Iteration :  28700
# [573/5000][49/51]	Loss_D: 0.0012	Loss_G: 14.8776	Real Score: 0.9999	 Fake Scores: 0.0011 / 0.0011
# Iteration :  28800
# [575/5000][49/51]	Loss_D: 0.0014	Loss_G: 14.1132	Real Score: 1.0000	 Fake Scores: 0.0014 / 0.0014
# Iteration :  28900
# [577/5000][49/51]	Loss_D: 0.0012	Loss_G: 12.7574	Real Score: 1.0000	 Fake Scores: 0.0011 / 0.0011
# Iteration :  29000
# [579/5000][49/51]	Loss_D: 0.0013	Loss_G: 13.9401	Real Score: 1.0000	 Fake Scores: 0.0013 / 0.0013
# Iteration :  29100
# [581/5000][49/51]	Loss_D: 0.0013	Loss_G: 13.6550	Real Score: 0.9999	 Fake Scores: 0.0012 / 0.0012
# Iteration :  29200
# [583/5000][49/51]	Loss_D: 0.0011	Loss_G: 12.8010	Real Score: 0.9999	 Fake Scores: 0.0010 / 0.0010
# Iteration :  29300
# [585/5000][49/51]	Loss_D: 0.0007	Loss_G: 13.2878	Real Score: 0.9999	 Fake Scores: 0.0006 / 0.0006
# Iteration :  29400
# [587/5000][49/51]	Loss_D: 0.0007	Loss_G: 13.4895	Real Score: 1.0000	 Fake Scores: 0.0006 / 0.0006
# Iteration :  29500
# [589/5000][49/51]	Loss_D: 0.0007	Loss_G: 13.5612	Real Score: 1.0000	 Fake Scores: 0.0006 / 0.0006
# Iteration :  29600
# [591/5000][49/51]	Loss_D: 0.0007	Loss_G: 13.5539	Real Score: 0.9999	 Fake Scores: 0.0007 / 0.0007
# Iteration :  29700
# [593/5000][49/51]	Loss_D: 0.0009	Loss_G: 13.0663	Real Score: 0.9999	 Fake Scores: 0.0008 / 0.0008
# Iteration :  29800
# [595/5000][49/51]	Loss_D: 0.0009	Loss_G: 13.1377	Real Score: 0.9999	 Fake Scores: 0.0008 / 0.0008
# Iteration :  29900
# [597/5000][49/51]	Loss_D: 0.0010	Loss_G: 13.0167	Real Score: 0.9999	 Fake Scores: 0.0009 / 0.0009
# Iteration :  30000
# [599/5000][49/51]	Loss_D: 0.0011	Loss_G: 12.8114	Real Score: 1.0000	 Fake Scores: 0.0011 / 0.0011
# Iteration :  30100
# [601/5000][49/51]	Loss_D: 0.0011	Loss_G: 13.0295	Real Score: 0.9999	 Fake Scores: 0.0010 / 0.0010
# Iteration :  30200
# [603/5000][49/51]	Loss_D: 0.0014	Loss_G: 12.8757	Real Score: 1.0000	 Fake Scores: 0.0013 / 0.0013
# Iteration :  30300
# [605/5000][49/51]	Loss_D: 0.0007	Loss_G: 14.1715	Real Score: 0.9999	 Fake Scores: 0.0006 / 0.0006
# Iteration :  30400
# [607/5000][49/51]	Loss_D: 0.0007	Loss_G: 14.5269	Real Score: 1.0000	 Fake Scores: 0.0006 / 0.0006
# Iteration :  30500
# [609/5000][49/51]	Loss_D: 0.0010	Loss_G: 13.4526	Real Score: 1.0000	 Fake Scores: 0.0010 / 0.0010
# Iteration :  30600
# [611/5000][49/51]	Loss_D: 0.0010	Loss_G: 13.8152	Real Score: 0.9999	 Fake Scores: 0.0010 / 0.0010
# Iteration :  30700
# [613/5000][49/51]	Loss_D: 0.0006	Loss_G: 13.1672	Real Score: 0.9999	 Fake Scores: 0.0005 / 0.0005
# Iteration :  30800
# [615/5000][49/51]	Loss_D: 0.0005	Loss_G: 13.4007	Real Score: 0.9999	 Fake Scores: 0.0004 / 0.0004
# Iteration :  30900
# [617/5000][49/51]	Loss_D: 0.0005	Loss_G: 13.4752	Real Score: 1.0000	 Fake Scores: 0.0004 / 0.0004
# Iteration :  31000
# [619/5000][49/51]	Loss_D: 0.0005	Loss_G: 13.4815	Real Score: 1.0000	 Fake Scores: 0.0004 / 0.0004
# Iteration :  31100
# [621/5000][49/51]	Loss_D: 0.0006	Loss_G: 13.4703	Real Score: 0.9999	 Fake Scores: 0.0004 / 0.0004
# Iteration :  31200
# [623/5000][49/51]	Loss_D: 0.0004	Loss_G: 13.4441	Real Score: 1.0000	 Fake Scores: 0.0004 / 0.0004
# Iteration :  31300
# [625/5000][49/51]	Loss_D: 0.0004	Loss_G: 13.4168	Real Score: 1.0000	 Fake Scores: 0.0004 / 0.0004
# Iteration :  31400
# [627/5000][49/51]	Loss_D: 0.0004	Loss_G: 13.3916	Real Score: 1.0000	 Fake Scores: 0.0004 / 0.0004
# Iteration :  31500
# [629/5000][49/51]	Loss_D: 0.0004	Loss_G: 13.3601	Real Score: 1.0000	 Fake Scores: 0.0004 / 0.0004
# Iteration :  31600
# [631/5000][49/51]	Loss_D: 0.0004	Loss_G: 13.3342	Real Score: 1.0000	 Fake Scores: 0.0004 / 0.0004
# Iteration :  31700
# [633/5000][49/51]	Loss_D: 0.0004	Loss_G: 13.2955	Real Score: 1.0000	 Fake Scores: 0.0004 / 0.0004
# Iteration :  31800
# [635/5000][49/51]	Loss_D: 0.0004	Loss_G: 13.2649	Real Score: 1.0000	 Fake Scores: 0.0004 / 0.0004
# Iteration :  31900
# [637/5000][49/51]	Loss_D: 0.0004	Loss_G: 13.2450	Real Score: 0.9999	 Fake Scores: 0.0004 / 0.0004
# Iteration :  32000
# [639/5000][49/51]	Loss_D: 0.0004	Loss_G: 13.2113	Real Score: 1.0000	 Fake Scores: 0.0004 / 0.0004
# Iteration :  32100
# [641/5000][49/51]	Loss_D: 0.0005	Loss_G: 13.1763	Real Score: 0.9999	 Fake Scores: 0.0004 / 0.0004
# Iteration :  32200
# [643/5000][49/51]	Loss_D: 0.0005	Loss_G: 13.1233	Real Score: 0.9999	 Fake Scores: 0.0004 / 0.0004
# Iteration :  32300
# [645/5000][49/51]	Loss_D: 0.0006	Loss_G: 13.0201	Real Score: 0.9999	 Fake Scores: 0.0005 / 0.0005
# Iteration :  32400
# [647/5000][49/51]	Loss_D: 0.0009	Loss_G: 12.1966	Real Score: 0.9999	 Fake Scores: 0.0009 / 0.0009
# Iteration :  32500
# [649/5000][49/51]	Loss_D: 0.0003	Loss_G: 16.0040	Real Score: 1.0000	 Fake Scores: 0.0003 / 0.0003
# Iteration :  32600
# [651/5000][49/51]	Loss_D: 0.0003	Loss_G: 15.4042	Real Score: 1.0000	 Fake Scores: 0.0003 / 0.0003
# Iteration :  32700
# [653/5000][49/51]	Loss_D: 0.0004	Loss_G: 14.9175	Real Score: 0.9999	 Fake Scores: 0.0003 / 0.0003
# Iteration :  32800
# [655/5000][49/51]	Loss_D: 0.0003	Loss_G: 14.5352	Real Score: 1.0000	 Fake Scores: 0.0003 / 0.0003
# Iteration :  32900
# [657/5000][49/51]	Loss_D: 0.0003	Loss_G: 14.2202	Real Score: 1.0000	 Fake Scores: 0.0003 / 0.0003
# Iteration :  33000
# [659/5000][49/51]	Loss_D: 0.0003	Loss_G: 13.9715	Real Score: 1.0000	 Fake Scores: 0.0003 / 0.0003
# Iteration :  33100
# [661/5000][49/51]	Loss_D: 0.0004	Loss_G: 13.7762	Real Score: 0.9999	 Fake Scores: 0.0003 / 0.0003
# Iteration :  33200
# [663/5000][49/51]	Loss_D: 0.0004	Loss_G: 13.6292	Real Score: 0.9999	 Fake Scores: 0.0003 / 0.0003
# Iteration :  33300
# [665/5000][49/51]	Loss_D: 0.0004	Loss_G: 13.5007	Real Score: 1.0000	 Fake Scores: 0.0003 / 0.0003
# Iteration :  33400
# [667/5000][49/51]	Loss_D: 0.0006	Loss_G: 13.0267	Real Score: 0.9999	 Fake Scores: 0.0005 / 0.0005
# Iteration :  33500
# [669/5000][49/51]	Loss_D: 0.0006	Loss_G: 12.7179	Real Score: 1.0000	 Fake Scores: 0.0006 / 0.0005
# Iteration :  33600
# [671/5000][49/51]	Loss_D: 0.0006	Loss_G: 12.6904	Real Score: 1.0000	 Fake Scores: 0.0006 / 0.0006
# Iteration :  33700
# [673/5000][49/51]	Loss_D: 0.0006	Loss_G: 13.1880	Real Score: 0.9999	 Fake Scores: 0.0005 / 0.0005
# Iteration :  33800
# [675/5000][49/51]	Loss_D: 0.0004	Loss_G: 14.1302	Real Score: 1.0000	 Fake Scores: 0.0004 / 0.0004
# Iteration :  33900
# [677/5000][49/51]	Loss_D: 0.0006	Loss_G: 12.6817	Real Score: 0.9999	 Fake Scores: 0.0005 / 0.0005
# Iteration :  34000
# [679/5000][49/51]	Loss_D: 0.0005	Loss_G: 13.3986	Real Score: 0.9999	 Fake Scores: 0.0005 / 0.0005
# Iteration :  34100
# [681/5000][49/51]	Loss_D: 0.0005	Loss_G: 13.3095	Real Score: 1.0000	 Fake Scores: 0.0005 / 0.0005
# Iteration :  34200
# [683/5000][49/51]	Loss_D: 0.0005	Loss_G: 13.7073	Real Score: 1.0000	 Fake Scores: 0.0004 / 0.0004
# Iteration :  34300
# [685/5000][49/51]	Loss_D: 0.0005	Loss_G: 13.7476	Real Score: 1.0000	 Fake Scores: 0.0004 / 0.0004
# Iteration :  34400
# [687/5000][49/51]	Loss_D: 0.0005	Loss_G: 13.2960	Real Score: 0.9999	 Fake Scores: 0.0004 / 0.0004
# Iteration :  34500
# [689/5000][49/51]	Loss_D: 0.0005	Loss_G: 13.7334	Real Score: 1.0000	 Fake Scores: 0.0004 / 0.0004
# Iteration :  34600
# [691/5000][49/51]	Loss_D: 0.0006	Loss_G: 13.3999	Real Score: 0.9999	 Fake Scores: 0.0005 / 0.0005
# Iteration :  34700
# [693/5000][49/51]	Loss_D: 0.0006	Loss_G: 14.1718	Real Score: 1.0000	 Fake Scores: 0.0005 / 0.0005
# Iteration :  34800
# [695/5000][49/51]	Loss_D: 0.0006	Loss_G: 14.3021	Real Score: 1.0000	 Fake Scores: 0.0006 / 0.0006
# Iteration :  34900
# [697/5000][49/51]	Loss_D: 0.0005	Loss_G: 14.7212	Real Score: 1.0000	 Fake Scores: 0.0004 / 0.0004
# Iteration :  35000
# [699/5000][49/51]	Loss_D: 0.0005	Loss_G: 14.0409	Real Score: 1.0000	 Fake Scores: 0.0004 / 0.0004
# Iteration :  35100
# [701/5000][49/51]	Loss_D: 0.0005	Loss_G: 14.1448	Real Score: 1.0000	 Fake Scores: 0.0005 / 0.0005
# Iteration :  35200
# [703/5000][49/51]	Loss_D: 0.0006	Loss_G: 13.3909	Real Score: 0.9999	 Fake Scores: 0.0005 / 0.0005
# Iteration :  35300
# [705/5000][49/51]	Loss_D: 0.0003	Loss_G: 14.1040	Real Score: 1.0000	 Fake Scores: 0.0002 / 0.0002
# Iteration :  35400
# [707/5000][49/51]	Loss_D: 0.0003	Loss_G: 13.8862	Real Score: 1.0000	 Fake Scores: 0.0002 / 0.0002
# Iteration :  35500
# [709/5000][49/51]	Loss_D: 0.0003	Loss_G: 13.7290	Real Score: 0.9999	 Fake Scores: 0.0002 / 0.0002
# Iteration :  35600
# [711/5000][49/51]	Loss_D: 0.0003	Loss_G: 13.5941	Real Score: 1.0000	 Fake Scores: 0.0002 / 0.0002
# Iteration :  35700
# [713/5000][49/51]	Loss_D: 0.0003	Loss_G: 13.4864	Real Score: 1.0000	 Fake Scores: 0.0002 / 0.0002
# Iteration :  35800
# [715/5000][49/51]	Loss_D: 0.0003	Loss_G: 13.3968	Real Score: 1.0000	 Fake Scores: 0.0002 / 0.0002
# Iteration :  35900
# [717/5000][49/51]	Loss_D: 0.0003	Loss_G: 13.3105	Real Score: 1.0000	 Fake Scores: 0.0002 / 0.0002
# Iteration :  36000
# [719/5000][49/51]	Loss_D: 0.0003	Loss_G: 13.2481	Real Score: 0.9999	 Fake Scores: 0.0002 / 0.0002
# Iteration :  36100
# [721/5000][49/51]	Loss_D: 0.0004	Loss_G: 14.4673	Real Score: 1.0000	 Fake Scores: 0.0004 / 0.0004
# Iteration :  36200
# [723/5000][49/51]	Loss_D: 0.0004	Loss_G: 14.0049	Real Score: 0.9999	 Fake Scores: 0.0003 / 0.0003
# Iteration :  36300
# [725/5000][49/51]	Loss_D: 0.0004	Loss_G: 13.0990	Real Score: 1.0000	 Fake Scores: 0.0004 / 0.0004
# Iteration :  36400
# Iteration :  38800
# [775/5000][49/51]	Loss_D: 0.0005	Loss_G: 9.7337	Real Score: 0.9998	 Fake Scores: 0.0003 / 0.0003
# Iteration :  38900
# [777/5000][49/51]	Loss_D: 0.0005	Loss_G: 10.3870	Real Score: 0.9998	 Fake Scores: 0.0002 / 0.0002
# Iteration :  39000
# [779/5000][49/51]	Loss_D: 0.0005	Loss_G: 10.8284	Real Score: 0.9998	 Fake Scores: 0.0002 / 0.0002
# Iteration :  39100
# [781/5000][49/51]	Loss_D: 0.0004	Loss_G: 11.0586	Real Score: 0.9998	 Fake Scores: 0.0002 / 0.0002
# Iteration :  39200
# [783/5000][49/51]	Loss_D: 0.0005	Loss_G: 10.0691	Real Score: 0.9997	 Fake Scores: 0.0002 / 0.0002
# Iteration :  39300
# [785/5000][49/51]	Loss_D: 0.0004	Loss_G: 10.0831	Real Score: 0.9998	 Fake Scores: 0.0002 / 0.0002
# Iteration :  39400
# [787/5000][49/51]	Loss_D: 0.0003	Loss_G: 10.7352	Real Score: 0.9998	 Fake Scores: 0.0001 / 0.0001
# Iteration :  39500
# [789/5000][49/51]	Loss_D: 0.0003	Loss_G: 11.1354	Real Score: 0.9998	 Fake Scores: 0.0001 / 0.0001
# Iteration :  39600
# [791/5000][49/51]	Loss_D: 0.0003	Loss_G: 11.1915	Real Score: 0.9999	 Fake Scores: 0.0001 / 0.0001
# Iteration :  39700
# [793/5000][49/51]	Loss_D: 0.0004	Loss_G: 12.8079	Real Score: 0.9998	 Fake Scores: 0.0001 / 0.0001
# Iteration :  39800
# [795/5000][49/51]	Loss_D: 0.0002	Loss_G: 13.1717	Real Score: 0.9999	 Fake Scores: 0.0001 / 0.0001
# Iteration :  39900
# [797/5000][49/51]	Loss_D: 0.0004	Loss_G: 13.2725	Real Score: 0.9999	 Fake Scores: 0.0001 / 0.0001
# Iteration :  40000
# [799/5000][49/51]	Loss_D: 0.0002	Loss_G: 14.2603	Real Score: 0.9999	 Fake Scores: 0.0001 / 0.0001
# Iteration :  40100
# [801/5000][49/51]	Loss_D: 0.0002	Loss_G: 14.2395	Real Score: 0.9999	 Fake Scores: 0.0001 / 0.0001
# Iteration :  40200
# [803/5000][49/51]	Loss_D: 0.0001	Loss_G: 14.1229	Real Score: 0.9999	 Fake Scores: 0.0000 / 0.0000
# Iteration :  40300
# [805/5000][49/51]	Loss_D: 0.0001	Loss_G: 13.9026	Real Score: 0.9999	 Fake Scores: 0.0000 / 0.0000
# Iteration :  40400
# [807/5000][49/51]	Loss_D: 0.0002	Loss_G: 13.8208	Real Score: 0.9999	 Fake Scores: 0.0000 / 0.0000
# Iteration :  40500
# [809/5000][49/51]	Loss_D: 0.0001	Loss_G: 13.7718	Real Score: 0.9999	 Fake Scores: 0.0000 / 0.0000
# Iteration :  40600
# [811/5000][49/51]	Loss_D: 0.0001	Loss_G: 13.7366	Real Score: 0.9999	 Fake Scores: 0.0000 / 0.0000
# Iteration :  40700
# [813/5000][49/51]	Loss_D: 0.0003	Loss_G: 13.6965	Real Score: 0.9998	 Fake Scores: 0.0001 / 0.0001
# Iteration :  40800
# [815/5000][49/51]	Loss_D: 0.0001	Loss_G: 13.6626	Real Score: 1.0000	 Fake Scores: 0.0001 / 0.0001
# Iteration :  40900
# [817/5000][49/51]	Loss_D: 0.0001	Loss_G: 13.6316	Real Score: 0.9999	 Fake Scores: 0.0001 / 0.0001
# Iteration :  41000
# [819/5000][49/51]	Loss_D: 0.0001	Loss_G: 13.7429	Real Score: 0.9999	 Fake Scores: 0.0001 / 0.0001
# Iteration :  41100
# [821/5000][49/51]	Loss_D: 0.0003	Loss_G: 13.9233	Real Score: 0.9999	 Fake Scores: 0.0001 / 0.0001
# Iteration :  41200
# [823/5000][49/51]	Loss_D: 0.0002	Loss_G: 14.1626	Real Score: 0.9999	 Fake Scores: 0.0001 / 0.0001
# Iteration :  41300
# [825/5000][49/51]	Loss_D: 0.0002	Loss_G: 14.2490	Real Score: 0.9999	 Fake Scores: 0.0001 / 0.0001
# Iteration :  41400
# [827/5000][49/51]	Loss_D: 0.0003	Loss_G: 14.2768	Real Score: 0.9999	 Fake Scores: 0.0001 / 0.0001
# Iteration :  41500
# [829/5000][49/51]	Loss_D: 0.0003	Loss_G: 14.2625	Real Score: 0.9999	 Fake Scores: 0.0001 / 0.0001
# Iteration :  41600
# ...
# Iteration :  236800
# [4735/5000][49/51]	Loss_D: 0.0002	Loss_G: 14.6543	Real Score: 0.9999	 Fake Scores: 0.0001 / 0.0001
# Iteration :  236900
# [4737/5000][49/51]	Loss_D: 0.0002	Loss_G: 15.4637	Real Score: 1.0000	 Fake Scores: 0.0001 / 0.0001
# Iteration :  237000
# [4739/5000][49/51]	Loss_D: 0.0002	Loss_G: 15.0284	Real Score: 0.9999	 Fake Scores: 0.0001 / 0.0001
# Iteration :  237100
# [4741/5000][49/51]	Loss_D: 0.0002	Loss_G: 14.8578	Real Score: 1.0000	 Fake Scores: 0.0001 / 0.0001
# Iteration :  237200
# [4743/5000][49/51]	Loss_D: 0.0002	Loss_G: 14.5051	Real Score: 0.9999	 Fake Scores: 0.0001 / 0.0001
# Iteration :  237300
# [4745/5000][49/51]	Loss_D: 0.0002	Loss_G: 14.3598	Real Score: 1.0000	 Fake Scores: 0.0002 / 0.0002
# Iteration :  237400
# [4747/5000][49/51]	Loss_D: 0.0004	Loss_G: 14.8515	Real Score: 0.9999	 Fake Scores: 0.0003 / 0.0003
# Iteration :  237500
# [4749/5000][49/51]	Loss_D: 0.0006	Loss_G: 14.6221	Real Score: 0.9999	 Fake Scores: 0.0005 / 0.0005
# Iteration :  237600
# [4751/5000][49/51]	Loss_D: 0.0007	Loss_G: 14.6015	Real Score: 0.9999	 Fake Scores: 0.0004 / 0.0004
# Iteration :  237700
# [4753/5000][49/51]	Loss_D: 0.0004	Loss_G: 14.5581	Real Score: 0.9999	 Fake Scores: 0.0003 / 0.0003
# Iteration :  237800
# [4755/5000][49/51]	Loss_D: 0.0003	Loss_G: 14.4560	Real Score: 0.9999	 Fake Scores: 0.0002 / 0.0002
# Iteration :  237900
# [4757/5000][49/51]	Loss_D: 0.0002	Loss_G: 14.3635	Real Score: 0.9999	 Fake Scores: 0.0002 / 0.0002
# Iteration :  238000
# [4759/5000][49/51]	Loss_D: 0.0004	Loss_G: 14.2416	Real Score: 0.9998	 Fake Scores: 0.0001 / 0.0001
# Iteration :  238100
# [4761/5000][49/51]	Loss_D: 0.0007	Loss_G: 14.0519	Real Score: 0.9999	 Fake Scores: 0.0004 / 0.0004
# Iteration :  238200
# [4763/5000][49/51]	Loss_D: 0.0006	Loss_G: 13.9619	Real Score: 0.9999	 Fake Scores: 0.0004 / 0.0004
# Iteration :  238300
# [4765/5000][49/51]	Loss_D: 0.0009	Loss_G: 13.7108	Real Score: 0.9999	 Fake Scores: 0.0006 / 0.0006
# Iteration :  238400
# [4767/5000][49/51]	Loss_D: 0.0007	Loss_G: 13.5397	Real Score: 0.9998	 Fake Scores: 0.0005 / 0.0005
# Iteration :  238500
# [4769/5000][49/51]	Loss_D: 0.0005	Loss_G: 13.6473	Real Score: 0.9999	 Fake Scores: 0.0004 / 0.0004
# Iteration :  238600
# [4771/5000][49/51]	Loss_D: 0.0005	Loss_G: 13.7227	Real Score: 0.9999	 Fake Scores: 0.0004 / 0.0004
Real Score: 0.9999	 Fake Scores: 0.0001 / 0.0001
# Iteration :  241100
# [4821/5000][49/51]	Loss_D: 0.0003	Loss_G: 14.2239	Real Score: 0.9999	 Fake Scores: 0.0002 / 0.0002
# Iteration :  241200
# [4823/5000][49/51]	Loss_D: 0.0002	Loss_G: 14.1262	Real Score: 0.9999	 Fake Scores: 0.0002 / 0.0002
# Iteration :  241300
# [4825/5000][49/51]	Loss_D: 0.0002	Loss_G: 14.1064	Real Score: 0.9999	 Fake Scores: 0.0002 / 0.0002
# Iteration :  241400
# [4827/5000][49/51]	Loss_D: 0.0003	Loss_G: 14.5421	Real Score: 0.9999	 Fake Scores: 0.0002 / 0.0002
# Iteration :  241500
# [4829/5000][49/51]	Loss_D: 0.0004	Loss_G: 14.4039	Real Score: 0.9999	 Fake Scores: 0.0002 / 0.0002
# Iteration :  241600
# [4831/5000][49/51]	Loss_D: 0.0006	Loss_G: 13.9693	Real Score: 0.9999	 Fake Scores: 0.0005 / 0.0005
# Iteration :  241700
# [4833/5000][49/51]	Loss_D: 0.0004	Loss_G: 14.3212	Real Score: 0.9999	 Fake Scores: 0.0003 / 0.0003
# Iteration :  241800
# [4835/5000][49/51]	Loss_D: 0.0005	Loss_G: 14.6362	Real Score: 0.9998	 Fake Scores: 0.0002 / 0.0002
# Iteration :  241900
# [4837/5000][49/51]	Loss_D: 0.0004	Loss_G: 14.2884	Real Score: 0.9999	 Fake Scores: 0.0003 / 0.0003
# Iteration :  242000
# [4839/5000][49/51]	Loss_D: 0.0004	Loss_G: 14.4337	Real Score: 0.9999	 Fake Scores: 0.0002 / 0.0002
# Iteration :  242100
# [4841/5000][49/51]	Loss_D: 0.0005	Loss_G: 14.6780	Real Score: 0.9998	 Fake Scores: 0.0002 / 0.0002
# Iteration :  242200
# [4843/5000][49/51]	Loss_D: 0.0003	Loss_G: 14.5641	Real Score: 0.9999	 Fake Scores: 0.0002 / 0.0002
# Iteration :  242300
# [4845/5000][49/51]	Loss_D: 0.0003	Loss_G: 14.4073	Real Score: 0.9999	 Fake Scores: 0.0001 / 0.0001
# Iteration :  242400
# [4847/5000][49/51]	Loss_D: 0.0003	Loss_G: 15.0118	Real Score: 0.9999	 Fake Scores: 0.0001 / 0.0001
# Iteration :  242500
# [4849/5000][49/51]	Loss_D: 0.0004	Loss_G: 14.7404	Real Score: 0.9999	 Fake Scores: 0.0002 / 0.0002
# Iteration :  242600
# [4851/5000][49/51]	Loss_D: 0.0003	Loss_G: 14.6272	Real Score: 0.9999	 Fake Scores: 0.0002 / 0.0002
# Iteration :  242700
# [4853/5000][49/51]	Loss_D: 0.0004	Loss_G: 14.2153	Real Score: 0.9999	 Fake Scores: 0.0002 / 0.0002
# Iteration :  242800
# [4855/5000][49/51]	Loss_D: 0.0004	Loss_G: 14.1967	Real Score: 0.9999	 Fake Scores: 0.0002 / 0.0002
# Iteration :  242900
# [4857/5000][49/51]	Loss_D: 0.0003	Loss_G: 14.2647	Real Score: 0.9999	 Fake Scores: 0.0002 / 0.0002
# Iteration :  243000
# [4859/5000][49/51]	Loss_D: 0.0002	Loss_G: 14.5916	Real Score: 0.9999	 Fake Scores: 0.0001 / 0.0001
# Iteration :  243100
# [4861/5000][49/51]	Loss_D: 0.0003	Loss_G: 14.7364	Real Score: 0.9999	 Fake Scores: 0.0002 / 0.0002
# Iteration :  243200
# [4863/5000][49/51]	Loss_D: 0.0003	Loss_G: 14.5723	Real Score: 0.9999	 Fake Scores: 0.0002 / 0.0002
# Iteration :  243300
# [4865/5000][49/51]	Loss_D: 0.0002	Loss_G: 14.6004	Real Score: 0.9999	 Fake Scores: 0.0001 / 0.0001
# Iteration :
Real Score: 0.9999	 Fake Scores: 0.0001 / 0.0001
# Iteration :  249200
# [4983/5000][49/51]	Loss_D: 0.0002	Loss_G: 14.6241	Real Score: 0.9999	 Fake Scores: 0.0001 / 0.0001
# Iteration :  249300
# [4985/5000][49/51]	Loss_D: 0.0001	Loss_G: 14.7480	Real Score: 0.9999	 Fake Scores: 0.0001 / 0.0001
# Iteration :  249400
# [4987/5000][49/51]	Loss_D: 0.0001	Loss_G: 14.2087	Real Score: 0.9999	 Fake Scores: 0.0001 / 0.0001
# Iteration :  249500
# [4989/5000][49/51]	Loss_D: 0.0003	Loss_G: 14.6345	Real Score: 0.9999	 Fake Scores: 0.0001 / 0.0001
# Iteration :  249600
# [4991/5000][49/51]	Loss_D: 0.0001	Loss_G: 14.5737	Real Score: 0.9999	 Fake Scores: 0.0001 / 0.0001
# Iteration :  249700
# [4993/5000][49/51]	Loss_D: 0.0003	Loss_G: 14.3736	Real Score: 0.9999	 Fake Scores: 0.0001 / 0.0001
# Iteration :  249800
# [4995/5000][49/51]	Loss_D: 0.0003	Loss_G: 15.9091	Real Score: 0.9999	 Fake Scores: 0.0002 / 0.0002
# Iteration :  249900
# [4997/5000][49/51]	Loss_D: 0.0004	Loss_G: 16.1886	Real Score: 0.9998	 Fake Scores: 0.0001 / 0.0001
# Iteration :  250000
# [4999/5000][49/51]	Loss_D: 0.0005	Loss_G: 15.1622	Real Score: 0.9999	 Fake Scores: 0.0004 / 0.0004
# Saved generator at /content/drive/My Drive/c147_project/Models/LSTM-LSTM/Generator_5000.pth

# %%
last_one = toy_GAN.generated_test[-1]
last_one = last_one
'''
xloc = np.arange(size)
newsize = 3153
new_xloc = np.linspace(0, size, newsize)
new_data = np.interp(new_xloc, xloc, data)
'''
# xloc = np.arange(last_one.shape[0])
# interp_loc = np.linspace(0, last_one.shape[0], 600)
# interp_last_one = np.interp(interp_loc, xloc, last_one)
plt.plot(last_one)

# %%
fig = plt.figure()
plt.plot(toy_GAN.G_loss, label='Generator Loss')
plt.plot(toy_GAN.D_loss, label='Discriminator Loss')
fig.suptitle('Generator Loss and Discriminator Loss vs Iteration for an LSTM-LSTM GAN')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.legend()
plt.show()
fig.savefig('GAN-LSTM-LSTM-GD-loss.jpg')

# %%
import torchinfo
# to run please add the hidden variable to the output of the generator
batch = 250
Gtest.to(device)
print(torchinfo.summary(Gtest, input_size=(250, 2, 100)))

Dtest.to(device)
print(torchinfo.summary(Dtest, input_size=(250, 22, 100)))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─LSTM: 1-1                              [250, 100, 44]            8,096
# ├─Sequential: 1-2                        [25000, 22]               --
# |    └─Linear: 2-1                       [25000, 22]               990
# |    └─Tanh: 2-2                         [25000, 22]               --
# ==========================================================================================
# Total params: 9,086
# Trainable params: 9,086
# Non-trainable params: 0
# Total mult-adds (M): 0.01
# ==========================================================================================
# Input size (MB): 0.20
# Forward/backward pass size (MB): 13.20
# Params size (MB): 0.04
# Estimated Total Size (MB): 13.44
# ==========================================================================================
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─LSTM: 1-1                              [250, 100, 44]            11,616
# ├─Sequential: 1-2                        [25000, 1]                --
# |    └─Linear: 2-1                       [25000, 1]                45
# |    └─Sigmoid: 2-2                      [25000, 1]                --
# ==========================================================================================
# Total params: 11,661
# Trainable params: 11,661
# Non-trainable params: 0
# Total mult-adds (M): 0.01
# ==========================================================================================
# Input size (MB): 2.20
# Forward/backward pass size (MB): 9.00
# Params size (MB): 0.05
# Estimated Total Size (MB): 11.25
# ==========================================================================================
